# %% [markdown]
# # Real-world network

# %%
import networkx as nx
from networkx.algorithms.centrality import *
import numpy as np
import operator
from analysis import *

# %%
g = nx.read_gml("./RealNetworks/budapest_connectome.gml")

# %%
print(nx.info(g))
# Out:
# Graph with 1015 nodes and 70654 edges
# <ipython-input-3-99dac2172e06>:1: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   print(nx.info(g))

# %% [markdown]
# # Check connectedness

# %%
nx.is_connected(g)
# Out:
# True

# %%
nx.number_connected_components(g)
# Out:
# 1

# %% [markdown]
# # Get LCC if graph is disconnected

# %% [raw]
# """Step 5: If the graph after immunization is disconnected, get the largest component"""
# g_lcc = nx.Graph()
#
# if nx.is_connected(g) == False:
#     largestComponents = [g.subgraph(c).copy() for c in sorted(nx.connected_components(g), key=len, reverse=True)]
#     print(nx.info(largestComponents[0]))
#
# g_lcc=largestComponents[0]
#
# print(nx.info(g_lcc))
#
# g = g_lcc
#
# print(nx.info(g))

# %% [markdown]
# # Relabel it all if nodes are strings
# - To be able to run all types of correlation together
# - But put the graph relabled in `g_relabled`

# %%
from myTruss import mappingAndRelabeling

# %%
g_relabled = mappingAndRelabeling(g)

# %%
print(nx.info(g))
print(nx.info(g_relabled))
# Out:
# Graph with 1015 nodes and 70654 edges
# Graph with 1015 nodes and 70654 edges
# <ipython-input-8-632c4a2d19f6>:1: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   print(nx.info(g))
# <ipython-input-8-632c4a2d19f6>:2: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   print(nx.info(g_relabled))

# %%
g = g_relabled

# %% [markdown]
# # Infer community structure with Louvain

# %%
nx.__version__
# Out:
# '2.8.4'

# %%
import pandas as pd
from os.path  import exists
import infomap as im

# %%
im.__version__
# Out:
# '2.3.0'

# %%
G = g

# %%
partition   = nx.algorithms.community.louvain_communities(G, seed = 0)
partition_Q = nx.algorithms.community.modularity(G, partition)

for seed in Bar("Progress", check_tty = False).iter(range(1,5)):
    partition_   = nx.algorithms.community.louvain_communities(G, seed = seed)
    partition_Q_ = nx.algorithms.community.modularity(G, partition_)
    
    if partition_Q_ > partition_Q:
        partition   = partition_
        partition_Q = partition_Q_
# Out:
# Progress |################################| 4/4

# %%
communities = { community_ID : set(community) for (community_ID, community) in enumerate(partition, start = 1)}

# %%
community_assignments = dict()
for (community_ID, community) in communities.items():
    for node in community:
        community_assignments[node] = community_ID

# %%
results_file = "./results/budapest_connectome-modularity.csv"

if not exists(results_file):
    # Map Equation Centrality
    tree_file = "./results/budapest_connectome-temp.tree"

    # use Infomap to write a tree file that we change to reflect the Louvain partition
    infomap = im.Infomap(silent = True, num_trials = 1, directed = False, two_level = True, seed = 42)
    infomap.add_networkx_graph(G)
    infomap.run()
    infomap.write_tree(tree_file)
    
    infomap_tree = dict()

    # read the tree file
    with open(tree_file, "r") as fh:
        for line in fh:
            if not line.startswith("#"):
                _, flow, name, node_id = line.strip().split(" ")
                name = name[1:-1]
                infomap_tree[int(name)] = (flow, node_id)
    
    # write the Louvain partition to an Infomap tree file
    with open("./results/budapest_connectome-modularity.tree", "w") as fh:
        for community_ID, community in enumerate(partition, start = 1):
            for node_pos, node in enumerate(community, start = 1):
                path = f"{community_ID}:{node_pos}"
                flow, node_id = infomap_tree[node]
                fh.write(f"{path} {flow} \"{node}\" {node_id}\n")
    
    # Load the Louvain partition with Infomap and use unrecorded link teleportation
    infomap2 = im.Infomap("--silent --no-infomap --cluster-data ./results/budapest_connectome-modularity.tree")
    node_mapping = infomap2.add_networkx_graph(G)
    infomap2.run()
    
    mec_ranks = [node for node, _score in sorted( [ (node_mapping[node.node_id], node.modular_centrality) for node in infomap2.iterLeafNodes() ]
                                                 , key     = second
                                                 , reverse = True
                                                 )]

    
    index = []
    for node in G.nodes:
        index.append(node)

    results = pd.DataFrame(index=index)

    results["map equation centrality rank"]       = toRanking(mec_ranks,        results.index)
    results.to_csv(results_file)

else:
    results = pd.read_csv(results_file, index_col = 0)

    mec_ranks         = mkRanks(results["map equation centrality rank"])

# %%
len(mec_ranks)
# Out:
# 1015

# %%
# node 107 has rank 0 (i.e. 1)
# node 1684 has rank 1 (i.e. 2)
# ...
# node 0 has rank 4 (i.e. 5)
mec_ranks
# Out:
# [187,
#  53,
#  52,
#  256,
#  96,
#  153,
#  403,
#  95,
#  621,
#  175,
#  145,
#  613,
#  501,
#  141,
#  402,
#  196,
#  623,
#  510,
#  91,
#  493,
#  144,
#  148,
#  654,
#  732,
#  64,
#  386,
#  131,
#  660,
#  511,
#  219,
#  736,
#  699,
#  500,
#  77,
#  142,
#  300,
#  726,
#  622,
#  92,
#  499,
#  130,
#  218,
#  707,
#  503,
#  133,
#  129,
#  656,
#  502,
#  147,
#  234,
#  276,
#  280,
#  513,
#  495,
#  734,
#  492,
#  704,
#  138,
#  563,
#  478,
#  217,
#  491,
#  149,
#  223,
#  46,
#  146,
#  464,
#  231,
#  708,
#  248,
#  75,
#  738,
#  761,
#  220,
#  270,
#  213,
#  311,
#  483,
#  516,
#  497,
#  332,
#  657,
#  655,
#  124,
#  123,
#  127,
#  652,
#  209,
#  661,
#  413,
#  197,
#  154,
#  277,
#  664,
#  230,
#  735,
#  120,
#  271,
#  288,
#  79,
#  614,
#  182,
#  696,
#  143,
#  475,
#  247,
#  468,
#  697,
#  481,
#  63,
#  282,
#  523,
#  58,
#  625,
#  467,
#  301,
#  727,
#  188,
#  494,
#  221,
#  659,
#  47,
#  128,
#  24,
#  200,
#  756,
#  461,
#  55,
#  620,
#  180,
#  799,
#  814,
#  210,
#  158,
#  856,
#  632,
#  466,
#  648,
#  211,
#  118,
#  76,
#  203,
#  89,
#  151,
#  779,
#  195,
#  126,
#  244,
#  476,
#  235,
#  460,
#  173,
#  82,
#  485,
#  782,
#  299,
#  471,
#  482,
#  388,
#  29,
#  228,
#  519,
#  156,
#  651,
#  633,
#  207,
#  722,
#  806,
#  518,
#  269,
#  312,
#  723,
#  101,
#  240,
#  214,
#  274,
#  720,
#  178,
#  456,
#  496,
#  286,
#  140,
#  698,
#  724,
#  278,
#  662,
#  194,
#  812,
#  331,
#  78,
#  224,
#  507,
#  672,
#  36,
#  315,
#  212,
#  139,
#  35,
#  104,
#  737,
#  619,
#  640,
#  204,
#  617,
#  258,
#  59,
#  39,
#  152,
#  828,
#  715,
#  308,
#  160,
#  193,
#  829,
#  509,
#  725,
#  624,
#  71,
#  215,
#  85,
#  791,
#  714,
#  90,
#  15,
#  45,
#  44,
#  487,
#  355,
#  181,
#  776,
#  729,
#  415,
#  687,
#  705,
#  189,
#  899,
#  810,
#  653,
#  615,
#  616,
#  359,
#  384,
#  353,
#  233,
#  773,
#  627,
#  304,
#  167,
#  232,
#  192,
#  328,
#  751,
#  325,
#  222,
#  205,
#  150,
#  634,
#  157,
#  815,
#  305,
#  479,
#  134,
#  88,
#  900,
#  855,
#  314,
#  80,
#  198,
#  488,
#  352,
#  351,
#  60,
#  13,
#  102,
#  853,
#  61,
#  38,
#  435,
#  473,
#  486,
#  811,
#  393,
#  170,
#  159,
#  848,
#  817,
#  826,
#  281,
#  863,
#  43,
#  885,
#  762,
#  297,
#  385,
#  752,
#  686,
#  462,
#  51,
#  428,
#  19,
#  34,
#  360,
#  512,
#  642,
#  747,
#  373,
#  119,
#  186,
#  741,
#  646,
#  169,
#  857,
#  172,
#  472,
#  453,
#  788,
#  264,
#  358,
#  287,
#  273,
#  174,
#  647,
#  261,
#  94,
#  201,
#  369,
#  645,
#  155,
#  813,
#  429,
#  268,
#  431,
#  800,
#  27,
#  504,
#  349,
#  649,
#  239,
#  498,
#  387,
#  808,
#  716,
#  107,
#  763,
#  40,
#  81,
#  166,
#  804,
#  275,
#  255,
#  103,
#  760,
#  469,
#  171,
#  368,
#  601,
#  115,
#  630,
#  748,
#  33,
#  132,
#  313,
#  465,
#  177,
#  12,
#  136,
#  859,
#  685,
#  719,
#  206,
#  87,
#  93,
#  905,
#  936,
#  392,
#  164,
#  257,
#  135,
#  505,
#  474,
#  262,
#  272,
#  254,
#  376,
#  922,
#  907,
#  954,
#  279,
#  618,
#  137,
#  121,
#  242,
#  784,
#  850,
#  265,
#  191,
#  910,
#  794,
#  717,
#  455,
#  706,
#  293,
#  208,
#  48,
#  866,
#  843,
#  684,
#  444,
#  663,
#  603,
#  298,
#  753,
#  742,
#  731,
#  650,
#  797,
#  323,
#  768,
#  179,
#  28,
#  229,
#  867,
#  949,
#  307,
#  306,
#  419,
#  772,
#  291,
#  3,
#  324,
#  163,
#  283,
#  774,
#  644,
#  847,
#  851,
#  302,
#  658,
#  86,
#  25,
#  83,
#  882,
#  849,
#  636,
#  674,
#  290,
#  438,
#  391,
#  757,
#  767,
#  694,
#  11,
#  454,
#  709,
#  821,
#  37,
#  944,
#  382,
#  347,
#  341,
#  395,
#  739,
#  795,
#  446,
#  860,
#  470,
#  263,
#  42,
#  74,
#  506,
#  759,
#  733,
#  841,
#  730,
#  245,
#  846,
#  713,
#  825,
#  778,
#  783,
#  530,
#  766,
#  754,
#  702,
#  463,
#  176,
#  545,
#  31,
#  335,
#  344,
#  940,
#  440,
#  326,
#  380,
#  837,
#  54,
#  183,
#  434,
#  834,
#  32,
#  72,
#  396,
#  775,
#  318,
#  842,
#  345,
#  404,
#  718,
#  260,
#  343,
#  917,
#  908,
#  941,
#  162,
#  517,
#  913,
#  541,
#  796,
#  100,
#  865,
#  508,
#  526,
#  423,
#  749,
#  342,
#  914,
#  897,
#  303,
#  405,
#  110,
#  117,
#  266,
#  447,
#  26,
#  943,
#  970,
#  951,
#  390,
#  878,
#  839,
#  934,
#  544,
#  786,
#  780,
#  673,
#  243,
#  202,
#  184,
#  10,
#  883,
#  971,
#  348,
#  769,
#  802,
#  168,
#  915,
#  937,
#  421,
#  771,
#  267,
#  99,
#  41,
#  111,
#  112,
#  912,
#  966,
#  976,
#  524,
#  536,
#  711,
#  745,
#  836,
#  354,
#  295,
#  165,
#  226,
#  216,
#  744,
#  755,
#  945,
#  533,
#  740,
#  932,
#  939,
#  968,
#  869,
#  383,
#  50,
#  361,
#  712,
#  682,
#  238,
#  336,
#  20,
#  401,
#  422,
#  426,
#  639,
#  801,
#  728,
#  65,
#  259,
#  984,
#  379,
#  822,
#  962,
#  844,
#  542,
#  366,
#  873,
#  831,
#  638,
#  125,
#  854,
#  972,
#  974,
#  877,
#  477,
#  641,
#  787,
#  666,
#  109,
#  947,
#  790,
#  902,
#  49,
#  539,
#  554,
#  701,
#  185,
#  607,
#  921,
#  534,
#  424,
#  824,
#  695,
#  374,
#  898,
#  540,
#  381,
#  743,
#  793,
#  942,
#  681,
#  227,
#  339,
#  876,
#  777,
#  562,
#  161,
#  553,
#  350,
#  480,
#  959,
#  578,
#  514,
#  555,
#  548,
#  252,
#  781,
#  935,
#  919,
#  631,
#  861,
#  57,
#  253,
#  370,
#  933,
#  294,
#  764,
#  820,
#  879,
#  7,
#  909,
#  538,
#  643,
#  67,
#  985,
#  950,
#  441,
#  437,
#  432,
#  693,
#  322,
#  329,
#  310,
#  17,
#  606,
#  449,
#  296,
#  823,
#  236,
#  911,
#  967,
#  669,
#  872,
#  73,
#  237,
#  363,
#  862,
#  515,
#  459,
#  785,
#  190,
#  319,
#  975,
#  346,
#  433,
#  564,
#  818,
#  362,
#  241,
#  963,
#  626,
#  700,
#  365,
#  284,
#  521,
#  430,
#  629,
#  378,
#  956,
#  977,
#  532,
#  552,
#  556,
#  327,
#  887,
#  122,
#  246,
#  789,
#  439,
#  6,
#  317,
#  412,
#  602,
#  892,
#  559,
#  703,
#  18,
#  16,
#  819,
#  721,
#  884,
#  250,
#  364,
#  23,
#  969,
#  688,
#  443,
#  683,
#  678,
#  870,
#  2,
#  978,
#  979,
#  406,
#  105,
#  330,
#  334,
#  973,
#  988,
#  547,
#  550,
#  199,
#  292,
#  924,
#  692,
#  886,
#  409,
#  321,
#  955,
#  980,
#  965,
#  987,
#  575,
#  561,
#  490,
#  840,
#  805,
#  14,
#  225,
#  394,
#  605,
#  875,
#  964,
#  952,
#  442,
#  888,
#  798,
#  765,
#  333,
#  316,
#  986,
#  572,
#  680,
#  357,
#  858,
#  981,
#  827,
#  62,
#  923,
#  990,
#  579,
#  585,
#  835,
#  845,
#  758,
#  408,
#  1001,
#  816,
#  445,
#  537,
#  484,
#  750,
#  397,
#  367,
#  546,
#  573,
#  904,
#  997,
#  991,
#  931,
#  792,
#  668,
#  9,
#  982,
#  427,
#  592,
#  832,
#  691,
#  285,
#  375,
#  30,
#  410,
#  938,
#  452,
#  70,
#  874,
#  451,
#  377,
#  558,
#  833,
#  746,
#  84,
#  309,
#  338,
#  340,
#  113,
#  675,
#  671,
#  251,
#  108,
#  1005,
#  1002,
#  566,
#  576,
#  665,
#  891,
#  320,
#  399,
#  679,
#  595,
#  531,
#  400,
#  557,
#  458,
#  809,
#  543,
#  586,
#  594,
#  520,
#  890,
#  106,
#  881,
#  903,
#  957,
#  587,
#  591,
#  569,
#  570,
#  581,
#  946,
#  983,
#  989,
#  582,
#  549,
#  1003,
#  906,
#  637,
#  807,
#  8,
#  289,
#  398,
#  929,
#  992,
#  930,
#  418,
#  1004,
#  593,
#  803,
#  628,
#  635,
#  889,
#  337,
#  116,
#  996,
#  588,
#  571,
#  489,
#  56,
#  1009,
#  589,
#  690,
#  830,
#  114,
#  66,
#  852,
#  450,
#  893,
#  21,
#  448,
#  574,
#  896,
#  0,
#  995,
#  920,
#  1000,
#  596,
#  604,
#  1006,
#  999,
#  567,
#  577,
#  868,
#  407,
#  249,
#  425,
#  994,
#  993,
#  710,
#  560,
#  535,
#  411,
#  918,
#  1010,
#  580,
#  676,
#  901,
#  389,
#  998,
#  598,
#  565,
#  98,
#  371,
#  436,
#  590,
#  1,
#  583,
#  527,
#  677,
#  871,
#  916,
#  689,
#  1007,
#  1008,
#  414,
#  22,
#  69,
#  522,
#  597,
#  838,
#  97,
#  925,
#  416,
#  356,
#  420,
#  948,
#  953,
#  457,
#  961,
#  551,
#  599,
#  417,
#  584,
#  5,
#  864,
#  372,
#  529,
#  600,
#  68,
#  895,
#  770,
#  670,
#  894,
#  927,
#  528,
#  4,
#  568,
#  926,
#  ...]

# %%
counter = len(mec_ranks)
dict_map_eq_centrality = {}

# %%
for node in mec_ranks:
    dict_map_eq_centrality[int(node)] = counter
    counter = counter - 1

# %%
dict_map_eq_centrality
# Out:
# {187: 1015,
#  53: 1014,
#  52: 1013,
#  256: 1012,
#  96: 1011,
#  153: 1010,
#  403: 1009,
#  95: 1008,
#  621: 1007,
#  175: 1006,
#  145: 1005,
#  613: 1004,
#  501: 1003,
#  141: 1002,
#  402: 1001,
#  196: 1000,
#  623: 999,
#  510: 998,
#  91: 997,
#  493: 996,
#  144: 995,
#  148: 994,
#  654: 993,
#  732: 992,
#  64: 991,
#  386: 990,
#  131: 989,
#  660: 988,
#  511: 987,
#  219: 986,
#  736: 985,
#  699: 984,
#  500: 983,
#  77: 982,
#  142: 981,
#  300: 980,
#  726: 979,
#  622: 978,
#  92: 977,
#  499: 976,
#  130: 975,
#  218: 974,
#  707: 973,
#  503: 972,
#  133: 971,
#  129: 970,
#  656: 969,
#  502: 968,
#  147: 967,
#  234: 966,
#  276: 965,
#  280: 964,
#  513: 963,
#  495: 962,
#  734: 961,
#  492: 960,
#  704: 959,
#  138: 958,
#  563: 957,
#  478: 956,
#  217: 955,
#  491: 954,
#  149: 953,
#  223: 952,
#  46: 951,
#  146: 950,
#  464: 949,
#  231: 948,
#  708: 947,
#  248: 946,
#  75: 945,
#  738: 944,
#  761: 943,
#  220: 942,
#  270: 941,
#  213: 940,
#  311: 939,
#  483: 938,
#  516: 937,
#  497: 936,
#  332: 935,
#  657: 934,
#  655: 933,
#  124: 932,
#  123: 931,
#  127: 930,
#  652: 929,
#  209: 928,
#  661: 927,
#  413: 926,
#  197: 925,
#  154: 924,
#  277: 923,
#  664: 922,
#  230: 921,
#  735: 920,
#  120: 919,
#  271: 918,
#  288: 917,
#  79: 916,
#  614: 915,
#  182: 914,
#  696: 913,
#  143: 912,
#  475: 911,
#  247: 910,
#  468: 909,
#  697: 908,
#  481: 907,
#  63: 906,
#  282: 905,
#  523: 904,
#  58: 903,
#  625: 902,
#  467: 901,
#  301: 900,
#  727: 899,
#  188: 898,
#  494: 897,
#  221: 896,
#  659: 895,
#  47: 894,
#  128: 893,
#  24: 892,
#  200: 891,
#  756: 890,
#  461: 889,
#  55: 888,
#  620: 887,
#  180: 886,
#  799: 885,
#  814: 884,
#  210: 883,
#  158: 882,
#  856: 881,
#  632: 880,
#  466: 879,
#  648: 878,
#  211: 877,
#  118: 876,
#  76: 875,
#  203: 874,
#  89: 873,
#  151: 872,
#  779: 871,
#  195: 870,
#  126: 869,
#  244: 868,
#  476: 867,
#  235: 866,
#  460: 865,
#  173: 864,
#  82: 863,
#  485: 862,
#  782: 861,
#  299: 860,
#  471: 859,
#  482: 858,
#  388: 857,
#  29: 856,
#  228: 855,
#  519: 854,
#  156: 853,
#  651: 852,
#  633: 851,
#  207: 850,
#  722: 849,
#  806: 848,
#  518: 847,
#  269: 846,
#  312: 845,
#  723: 844,
#  101: 843,
#  240: 842,
#  214: 841,
#  274: 840,
#  720: 839,
#  178: 838,
#  456: 837,
#  496: 836,
#  286: 835,
#  140: 834,
#  698: 833,
#  724: 832,
#  278: 831,
#  662: 830,
#  194: 829,
#  812: 828,
#  331: 827,
#  78: 826,
#  224: 825,
#  507: 824,
#  672: 823,
#  36: 822,
#  315: 821,
#  212: 820,
#  139: 819,
#  35: 818,
#  104: 817,
#  737: 816,
#  619: 815,
#  640: 814,
#  204: 813,
#  617: 812,
#  258: 811,
#  59: 810,
#  39: 809,
#  152: 808,
#  828: 807,
#  715: 806,
#  308: 805,
#  160: 804,
#  193: 803,
#  829: 802,
#  509: 801,
#  725: 800,
#  624: 799,
#  71: 798,
#  215: 797,
#  85: 796,
#  791: 795,
#  714: 794,
#  90: 793,
#  15: 792,
#  45: 791,
#  44: 790,
#  487: 789,
#  355: 788,
#  181: 787,
#  776: 786,
#  729: 785,
#  415: 784,
#  687: 783,
#  705: 782,
#  189: 781,
#  899: 780,
#  810: 779,
#  653: 778,
#  615: 777,
#  616: 776,
#  359: 775,
#  384: 774,
#  353: 773,
#  233: 772,
#  773: 771,
#  627: 770,
#  304: 769,
#  167: 768,
#  232: 767,
#  192: 766,
#  328: 765,
#  751: 764,
#  325: 763,
#  222: 762,
#  205: 761,
#  150: 760,
#  634: 759,
#  157: 758,
#  815: 757,
#  305: 756,
#  479: 755,
#  134: 754,
#  88: 753,
#  900: 752,
#  855: 751,
#  314: 750,
#  80: 749,
#  198: 748,
#  488: 747,
#  352: 746,
#  351: 745,
#  60: 744,
#  13: 743,
#  102: 742,
#  853: 741,
#  61: 740,
#  38: 739,
#  435: 738,
#  473: 737,
#  486: 736,
#  811: 735,
#  393: 734,
#  170: 733,
#  159: 732,
#  848: 731,
#  817: 730,
#  826: 729,
#  281: 728,
#  863: 727,
#  43: 726,
#  885: 725,
#  762: 724,
#  297: 723,
#  385: 722,
#  752: 721,
#  686: 720,
#  462: 719,
#  51: 718,
#  428: 717,
#  19: 716,
#  34: 715,
#  360: 714,
#  512: 713,
#  642: 712,
#  747: 711,
#  373: 710,
#  119: 709,
#  186: 708,
#  741: 707,
#  646: 706,
#  169: 705,
#  857: 704,
#  172: 703,
#  472: 702,
#  453: 701,
#  788: 700,
#  264: 699,
#  358: 698,
#  287: 697,
#  273: 696,
#  174: 695,
#  647: 694,
#  261: 693,
#  94: 692,
#  201: 691,
#  369: 690,
#  645: 689,
#  155: 688,
#  813: 687,
#  429: 686,
#  268: 685,
#  431: 684,
#  800: 683,
#  27: 682,
#  504: 681,
#  349: 680,
#  649: 679,
#  239: 678,
#  498: 677,
#  387: 676,
#  808: 675,
#  716: 674,
#  107: 673,
#  763: 672,
#  40: 671,
#  81: 670,
#  166: 669,
#  804: 668,
#  275: 667,
#  255: 666,
#  103: 665,
#  760: 664,
#  469: 663,
#  171: 662,
#  368: 661,
#  601: 660,
#  115: 659,
#  630: 658,
#  748: 657,
#  33: 656,
#  132: 655,
#  313: 654,
#  465: 653,
#  177: 652,
#  12: 651,
#  136: 650,
#  859: 649,
#  685: 648,
#  719: 647,
#  206: 646,
#  87: 645,
#  93: 644,
#  905: 643,
#  936: 642,
#  392: 641,
#  164: 640,
#  257: 639,
#  135: 638,
#  505: 637,
#  474: 636,
#  262: 635,
#  272: 634,
#  254: 633,
#  376: 632,
#  922: 631,
#  907: 630,
#  954: 629,
#  279: 628,
#  618: 627,
#  137: 626,
#  121: 625,
#  242: 624,
#  784: 623,
#  850: 622,
#  265: 621,
#  191: 620,
#  910: 619,
#  794: 618,
#  717: 617,
#  455: 616,
#  706: 615,
#  293: 614,
#  208: 613,
#  48: 612,
#  866: 611,
#  843: 610,
#  684: 609,
#  444: 608,
#  663: 607,
#  603: 606,
#  298: 605,
#  753: 604,
#  742: 603,
#  731: 602,
#  650: 601,
#  797: 600,
#  323: 599,
#  768: 598,
#  179: 597,
#  28: 596,
#  229: 595,
#  867: 594,
#  949: 593,
#  307: 592,
#  306: 591,
#  419: 590,
#  772: 589,
#  291: 588,
#  3: 587,
#  324: 586,
#  163: 585,
#  283: 584,
#  774: 583,
#  644: 582,
#  847: 581,
#  851: 580,
#  302: 579,
#  658: 578,
#  86: 577,
#  25: 576,
#  83: 575,
#  882: 574,
#  849: 573,
#  636: 572,
#  674: 571,
#  290: 570,
#  438: 569,
#  391: 568,
#  757: 567,
#  767: 566,
#  694: 565,
#  11: 564,
#  454: 563,
#  709: 562,
#  821: 561,
#  37: 560,
#  944: 559,
#  382: 558,
#  347: 557,
#  341: 556,
#  395: 555,
#  739: 554,
#  795: 553,
#  446: 552,
#  860: 551,
#  470: 550,
#  263: 549,
#  42: 548,
#  74: 547,
#  506: 546,
#  759: 545,
#  733: 544,
#  841: 543,
#  730: 542,
#  245: 541,
#  846: 540,
#  713: 539,
#  825: 538,
#  778: 537,
#  783: 536,
#  530: 535,
#  766: 534,
#  754: 533,
#  702: 532,
#  463: 531,
#  176: 530,
#  545: 529,
#  31: 528,
#  335: 527,
#  344: 526,
#  940: 525,
#  440: 524,
#  326: 523,
#  380: 522,
#  837: 521,
#  54: 520,
#  183: 519,
#  434: 518,
#  834: 517,
#  32: 516,
#  72: 515,
#  396: 514,
#  775: 513,
#  318: 512,
#  842: 511,
#  345: 510,
#  404: 509,
#  718: 508,
#  260: 507,
#  343: 506,
#  917: 505,
#  908: 504,
#  941: 503,
#  162: 502,
#  517: 501,
#  913: 500,
#  541: 499,
#  796: 498,
#  100: 497,
#  865: 496,
#  508: 495,
#  526: 494,
#  423: 493,
#  749: 492,
#  342: 491,
#  914: 490,
#  897: 489,
#  303: 488,
#  405: 487,
#  110: 486,
#  117: 485,
#  266: 484,
#  447: 483,
#  26: 482,
#  943: 481,
#  970: 480,
#  951: 479,
#  390: 478,
#  878: 477,
#  839: 476,
#  934: 475,
#  544: 474,
#  786: 473,
#  780: 472,
#  673: 471,
#  243: 470,
#  202: 469,
#  184: 468,
#  10: 467,
#  883: 466,
#  971: 465,
#  348: 464,
#  769: 463,
#  802: 462,
#  168: 461,
#  915: 460,
#  937: 459,
#  421: 458,
#  771: 457,
#  267: 456,
#  99: 455,
#  41: 454,
#  111: 453,
#  112: 452,
#  912: 451,
#  966: 450,
#  976: 449,
#  524: 448,
#  536: 447,
#  711: 446,
#  745: 445,
#  836: 444,
#  354: 443,
#  295: 442,
#  165: 441,
#  226: 440,
#  216: 439,
#  744: 438,
#  755: 437,
#  945: 436,
#  533: 435,
#  740: 434,
#  932: 433,
#  939: 432,
#  968: 431,
#  869: 430,
#  383: 429,
#  50: 428,
#  361: 427,
#  712: 426,
#  682: 425,
#  238: 424,
#  336: 423,
#  20: 422,
#  401: 421,
#  422: 420,
#  426: 419,
#  639: 418,
#  801: 417,
#  728: 416,
#  65: 415,
#  259: 414,
#  984: 413,
#  379: 412,
#  822: 411,
#  962: 410,
#  844: 409,
#  542: 408,
#  366: 407,
#  873: 406,
#  831: 405,
#  638: 404,
#  125: 403,
#  854: 402,
#  972: 401,
#  974: 400,
#  877: 399,
#  477: 398,
#  641: 397,
#  787: 396,
#  666: 395,
#  109: 394,
#  947: 393,
#  790: 392,
#  902: 391,
#  49: 390,
#  539: 389,
#  554: 388,
#  701: 387,
#  185: 386,
#  607: 385,
#  921: 384,
#  534: 383,
#  424: 382,
#  824: 381,
#  695: 380,
#  374: 379,
#  898: 378,
#  540: 377,
#  381: 376,
#  743: 375,
#  793: 374,
#  942: 373,
#  681: 372,
#  227: 371,
#  339: 370,
#  876: 369,
#  777: 368,
#  562: 367,
#  161: 366,
#  553: 365,
#  350: 364,
#  480: 363,
#  959: 362,
#  578: 361,
#  514: 360,
#  555: 359,
#  548: 358,
#  252: 357,
#  781: 356,
#  935: 355,
#  919: 354,
#  631: 353,
#  861: 352,
#  57: 351,
#  253: 350,
#  370: 349,
#  933: 348,
#  294: 347,
#  764: 346,
#  820: 345,
#  879: 344,
#  7: 343,
#  909: 342,
#  538: 341,
#  643: 340,
#  67: 339,
#  985: 338,
#  950: 337,
#  441: 336,
#  437: 335,
#  432: 334,
#  693: 333,
#  322: 332,
#  329: 331,
#  310: 330,
#  17: 329,
#  606: 328,
#  449: 327,
#  296: 326,
#  823: 325,
#  236: 324,
#  911: 323,
#  967: 322,
#  669: 321,
#  872: 320,
#  73: 319,
#  237: 318,
#  363: 317,
#  862: 316,
#  515: 315,
#  459: 314,
#  785: 313,
#  190: 312,
#  319: 311,
#  975: 310,
#  346: 309,
#  433: 308,
#  564: 307,
#  818: 306,
#  362: 305,
#  241: 304,
#  963: 303,
#  626: 302,
#  700: 301,
#  365: 300,
#  284: 299,
#  521: 298,
#  430: 297,
#  629: 296,
#  378: 295,
#  956: 294,
#  977: 293,
#  532: 292,
#  552: 291,
#  556: 290,
#  327: 289,
#  887: 288,
#  122: 287,
#  246: 286,
#  789: 285,
#  439: 284,
#  6: 283,
#  317: 282,
#  412: 281,
#  602: 280,
#  892: 279,
#  559: 278,
#  703: 277,
#  18: 276,
#  16: 275,
#  819: 274,
#  721: 273,
#  884: 272,
#  250: 271,
#  364: 270,
#  23: 269,
#  969: 268,
#  688: 267,
#  443: 266,
#  683: 265,
#  678: 264,
#  870: 263,
#  2: 262,
#  978: 261,
#  979: 260,
#  406: 259,
#  105: 258,
#  330: 257,
#  334: 256,
#  973: 255,
#  988: 254,
#  547: 253,
#  550: 252,
#  199: 251,
#  292: 250,
#  924: 249,
#  692: 248,
#  886: 247,
#  409: 246,
#  321: 245,
#  955: 244,
#  980: 243,
#  965: 242,
#  987: 241,
#  575: 240,
#  561: 239,
#  490: 238,
#  840: 237,
#  805: 236,
#  14: 235,
#  225: 234,
#  394: 233,
#  605: 232,
#  875: 231,
#  964: 230,
#  952: 229,
#  442: 228,
#  888: 227,
#  798: 226,
#  765: 225,
#  333: 224,
#  316: 223,
#  986: 222,
#  572: 221,
#  680: 220,
#  357: 219,
#  858: 218,
#  981: 217,
#  827: 216,
#  62: 215,
#  923: 214,
#  990: 213,
#  579: 212,
#  585: 211,
#  835: 210,
#  845: 209,
#  758: 208,
#  408: 207,
#  1001: 206,
#  816: 205,
#  445: 204,
#  537: 203,
#  484: 202,
#  750: 201,
#  397: 200,
#  367: 199,
#  546: 198,
#  573: 197,
#  904: 196,
#  997: 195,
#  991: 194,
#  931: 193,
#  792: 192,
#  668: 191,
#  9: 190,
#  982: 189,
#  427: 188,
#  592: 187,
#  832: 186,
#  691: 185,
#  285: 184,
#  375: 183,
#  30: 182,
#  410: 181,
#  938: 180,
#  452: 179,
#  70: 178,
#  874: 177,
#  451: 176,
#  377: 175,
#  558: 174,
#  833: 173,
#  746: 172,
#  84: 171,
#  309: 170,
#  338: 169,
#  340: 168,
#  113: 167,
#  675: 166,
#  671: 165,
#  251: 164,
#  108: 163,
#  1005: 162,
#  1002: 161,
#  566: 160,
#  576: 159,
#  665: 158,
#  891: 157,
#  320: 156,
#  399: 155,
#  679: 154,
#  595: 153,
#  531: 152,
#  400: 151,
#  557: 150,
#  458: 149,
#  809: 148,
#  543: 147,
#  586: 146,
#  594: 145,
#  520: 144,
#  890: 143,
#  106: 142,
#  881: 141,
#  903: 140,
#  957: 139,
#  587: 138,
#  591: 137,
#  569: 136,
#  570: 135,
#  581: 134,
#  946: 133,
#  983: 132,
#  989: 131,
#  582: 130,
#  549: 129,
#  1003: 128,
#  906: 127,
#  637: 126,
#  807: 125,
#  8: 124,
#  289: 123,
#  398: 122,
#  929: 121,
#  992: 120,
#  930: 119,
#  418: 118,
#  1004: 117,
#  593: 116,
#  803: 115,
#  628: 114,
#  635: 113,
#  889: 112,
#  337: 111,
#  116: 110,
#  996: 109,
#  588: 108,
#  571: 107,
#  489: 106,
#  56: 105,
#  1009: 104,
#  589: 103,
#  690: 102,
#  830: 101,
#  114: 100,
#  66: 99,
#  852: 98,
#  450: 97,
#  893: 96,
#  21: 95,
#  448: 94,
#  574: 93,
#  896: 92,
#  0: 91,
#  995: 90,
#  920: 89,
#  1000: 88,
#  596: 87,
#  604: 86,
#  1006: 85,
#  999: 84,
#  567: 83,
#  577: 82,
#  868: 81,
#  407: 80,
#  249: 79,
#  425: 78,
#  994: 77,
#  993: 76,
#  710: 75,
#  560: 74,
#  535: 73,
#  411: 72,
#  918: 71,
#  1010: 70,
#  580: 69,
#  676: 68,
#  901: 67,
#  389: 66,
#  998: 65,
#  598: 64,
#  565: 63,
#  98: 62,
#  371: 61,
#  436: 60,
#  590: 59,
#  1: 58,
#  583: 57,
#  527: 56,
#  677: 55,
#  871: 54,
#  916: 53,
#  689: 52,
#  1007: 51,
#  1008: 50,
#  414: 49,
#  22: 48,
#  69: 47,
#  522: 46,
#  597: 45,
#  838: 44,
#  97: 43,
#  925: 42,
#  416: 41,
#  356: 40,
#  420: 39,
#  948: 38,
#  953: 37,
#  457: 36,
#  961: 35,
#  551: 34,
#  599: 33,
#  417: 32,
#  584: 31,
#  5: 30,
#  864: 29,
#  372: 28,
#  529: 27,
#  600: 26,
#  68: 25,
#  895: 24,
#  770: 23,
#  670: 22,
#  894: 21,
#  927: 20,
#  528: 19,
#  4: 18,
#  568: 17,
#  926: 16,
#  ...}

# %%
# Write Centrality
with open('./MapEquationCentralityResults/Bio-BudapestConnectome/dict_map_eq_centrality.txt', 'w') as f:
    for key, value in dict_map_eq_centrality.items():
        f.write('%s:%s\n' % (key, value))

# %%
# Read Centrality
dict_map_eq_centrality_read = dict()
with open('./MapEquationCentralityResults/Bio-BudapestConnectome/dict_map_eq_centrality.txt') as raw_data:
    for item in raw_data:
        if ':' in item:
            key,value = item.split(':', 1)
            value = value.replace('\n', '')
            dict_map_eq_centrality_read[int(key)]=float(value)
        else:
            pass # deal with bad lines of text here

# %%
dict_map_eq_centrality_read == dict_map_eq_centrality
# Out:
# True
