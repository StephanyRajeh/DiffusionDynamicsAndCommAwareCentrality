# %% [markdown]
# # Real-world network

# %%
import networkx as nx
from networkx.algorithms.centrality import *
import numpy as np
import operator
from analysis import *

# %%
g = nx.read_gml("./RealNetworks/eu_airlines.gml")

# %%
print(nx.info(g))
# Out:
# Graph with 417 nodes and 2953 edges
# <ipython-input-3-99dac2172e06>:1: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   print(nx.info(g))

# %% [markdown]
# # Check connectedness

# %%
nx.is_connected(g)
# Out:
# True

# %%
nx.number_connected_components(g)
# Out:
# 1

# %% [markdown]
# # Get LCC if graph is disconnected

# %% [raw]
# """Step 5: If the graph after immunization is disconnected, get the largest component"""
# g_lcc = nx.Graph()
#
# if nx.is_connected(g) == False:
#     largestComponents = [g.subgraph(c).copy() for c in sorted(nx.connected_components(g), key=len, reverse=True)]
#     print(nx.info(largestComponents[0]))
#
# g_lcc=largestComponents[0]
#
# print(nx.info(g_lcc))
#
# g = g_lcc
#
# print(nx.info(g))

# %% [markdown]
# # Relabel it all if nodes are strings
# - To be able to run all types of correlation together
# - But put the graph relabled in `g_relabled`

# %%
from myTruss import mappingAndRelabeling

# %%
g_relabled = mappingAndRelabeling(g)

# %%
print(nx.info(g))
print(nx.info(g_relabled))
# Out:
# Graph with 417 nodes and 2953 edges
# Graph with 417 nodes and 2953 edges
# <ipython-input-8-632c4a2d19f6>:1: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   print(nx.info(g))
# <ipython-input-8-632c4a2d19f6>:2: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   print(nx.info(g_relabled))

# %%
g = g_relabled

# %% [markdown]
# # Infer community structure with Louvain

# %%
nx.__version__
# Out:
# '2.8.4'

# %%
import pandas as pd
from os.path  import exists
import infomap as im

# %%
im.__version__
# Out:
# '2.3.0'

# %%
G = g

# %%
partition   = nx.algorithms.community.louvain_communities(G, seed = 0)
partition_Q = nx.algorithms.community.modularity(G, partition)

for seed in Bar("Progress", check_tty = False).iter(range(1,5)):
    partition_   = nx.algorithms.community.louvain_communities(G, seed = seed)
    partition_Q_ = nx.algorithms.community.modularity(G, partition_)
    
    if partition_Q_ > partition_Q:
        partition   = partition_
        partition_Q = partition_Q_
# Out:
# Progress |################################| 4/4

# %%
communities = { community_ID : set(community) for (community_ID, community) in enumerate(partition, start = 1)}

# %%
community_assignments = dict()
for (community_ID, community) in communities.items():
    for node in community:
        community_assignments[node] = community_ID

# %%
results_file = "./results/eu_airlines-modularity.csv"

if not exists(results_file):
    # Map Equation Centrality
    tree_file = "./results/eu_airlines-temp.tree"

    # use Infomap to write a tree file that we change to reflect the Louvain partition
    infomap = im.Infomap(silent = True, num_trials = 1, directed = False, two_level = True, seed = 42)
    infomap.add_networkx_graph(G)
    infomap.run()
    infomap.write_tree(tree_file)
    
    infomap_tree = dict()

    # read the tree file
    with open(tree_file, "r") as fh:
        for line in fh:
            if not line.startswith("#"):
                _, flow, name, node_id = line.strip().split(" ")
                name = name[1:-1]
                infomap_tree[int(name)] = (flow, node_id)
    
    # write the Louvain partition to an Infomap tree file
    with open("./results/eu_airlines-modularity.tree", "w") as fh:
        for community_ID, community in enumerate(partition, start = 1):
            for node_pos, node in enumerate(community, start = 1):
                path = f"{community_ID}:{node_pos}"
                flow, node_id = infomap_tree[node]
                fh.write(f"{path} {flow} \"{node}\" {node_id}\n")
    
    # Load the Louvain partition with Infomap and use unrecorded link teleportation
    infomap2 = im.Infomap("--silent --no-infomap --cluster-data ./results/eu_airlines-modularity.tree")
    node_mapping = infomap2.add_networkx_graph(G)
    infomap2.run()
    
    mec_ranks = [node for node, _score in sorted( [ (node_mapping[node.node_id], node.modular_centrality) for node in infomap2.iterLeafNodes() ]
                                                 , key     = second
                                                 , reverse = True
                                                 )]

    
    index = []
    for node in G.nodes:
        index.append(node)

    results = pd.DataFrame(index=index)

    results["map equation centrality rank"]       = toRanking(mec_ranks,        results.index)
    results.to_csv(results_file)

else:
    results = pd.read_csv(results_file, index_col = 0)

    mec_ranks         = mkRanks(results["map equation centrality rank"])

# %%
len(mec_ranks)
# Out:
# 417

# %%
# node 107 has rank 0 (i.e. 1)
# node 1684 has rank 1 (i.e. 2)
# ...
# node 0 has rank 4 (i.e. 5)
mec_ranks
# Out:
# [83,
#  17,
#  2,
#  3,
#  35,
#  30,
#  1,
#  57,
#  5,
#  38,
#  21,
#  52,
#  63,
#  14,
#  10,
#  22,
#  43,
#  12,
#  95,
#  23,
#  112,
#  96,
#  13,
#  7,
#  42,
#  28,
#  26,
#  4,
#  56,
#  54,
#  44,
#  59,
#  73,
#  85,
#  48,
#  47,
#  24,
#  19,
#  70,
#  66,
#  92,
#  8,
#  164,
#  101,
#  20,
#  98,
#  41,
#  106,
#  141,
#  16,
#  50,
#  91,
#  103,
#  124,
#  18,
#  60,
#  114,
#  142,
#  140,
#  39,
#  163,
#  171,
#  111,
#  37,
#  90,
#  102,
#  157,
#  130,
#  40,
#  45,
#  174,
#  75,
#  11,
#  33,
#  167,
#  88,
#  25,
#  97,
#  58,
#  34,
#  15,
#  31,
#  29,
#  67,
#  68,
#  187,
#  170,
#  89,
#  79,
#  105,
#  69,
#  169,
#  236,
#  77,
#  121,
#  126,
#  168,
#  46,
#  36,
#  155,
#  127,
#  84,
#  134,
#  240,
#  80,
#  159,
#  62,
#  86,
#  172,
#  173,
#  154,
#  252,
#  6,
#  322,
#  81,
#  148,
#  27,
#  78,
#  99,
#  49,
#  150,
#  119,
#  71,
#  0,
#  87,
#  246,
#  72,
#  307,
#  53,
#  51,
#  32,
#  61,
#  166,
#  160,
#  115,
#  249,
#  128,
#  109,
#  125,
#  108,
#  323,
#  55,
#  65,
#  182,
#  184,
#  185,
#  122,
#  176,
#  188,
#  244,
#  207,
#  156,
#  178,
#  74,
#  175,
#  165,
#  193,
#  123,
#  190,
#  9,
#  239,
#  158,
#  180,
#  195,
#  250,
#  259,
#  248,
#  104,
#  219,
#  324,
#  329,
#  118,
#  260,
#  153,
#  120,
#  385,
#  379,
#  93,
#  265,
#  147,
#  209,
#  264,
#  181,
#  151,
#  191,
#  261,
#  192,
#  326,
#  107,
#  354,
#  117,
#  351,
#  245,
#  346,
#  258,
#  82,
#  311,
#  312,
#  308,
#  374,
#  131,
#  136,
#  212,
#  217,
#  162,
#  253,
#  143,
#  199,
#  208,
#  149,
#  116,
#  272,
#  76,
#  152,
#  210,
#  391,
#  316,
#  242,
#  383,
#  382,
#  129,
#  135,
#  137,
#  139,
#  247,
#  291,
#  290,
#  285,
#  344,
#  274,
#  255,
#  254,
#  179,
#  197,
#  186,
#  205,
#  269,
#  113,
#  348,
#  342,
#  110,
#  198,
#  144,
#  295,
#  355,
#  392,
#  310,
#  319,
#  396,
#  406,
#  314,
#  376,
#  377,
#  133,
#  138,
#  277,
#  94,
#  225,
#  256,
#  356,
#  352,
#  350,
#  211,
#  337,
#  270,
#  177,
#  201,
#  340,
#  146,
#  296,
#  266,
#  145,
#  400,
#  328,
#  243,
#  395,
#  309,
#  313,
#  320,
#  318,
#  384,
#  381,
#  393,
#  132,
#  273,
#  283,
#  286,
#  361,
#  362,
#  366,
#  372,
#  367,
#  267,
#  271,
#  293,
#  298,
#  300,
#  64,
#  215,
#  327,
#  343,
#  221,
#  228,
#  345,
#  357,
#  360,
#  341,
#  334,
#  332,
#  189,
#  194,
#  196,
#  331,
#  200,
#  202,
#  407,
#  330,
#  403,
#  390,
#  414,
#  397,
#  401,
#  338,
#  347,
#  204,
#  263,
#  398,
#  321,
#  369,
#  370,
#  183,
#  315,
#  375,
#  387,
#  378,
#  380,
#  317,
#  394,
#  276,
#  279,
#  288,
#  287,
#  268,
#  275,
#  251,
#  302,
#  371,
#  301,
#  353,
#  257,
#  402,
#  100,
#  413,
#  297,
#  306,
#  358,
#  294,
#  359,
#  213,
#  214,
#  305,
#  216,
#  304,
#  218,
#  292,
#  220,
#  303,
#  222,
#  223,
#  161,
#  299,
#  226,
#  227,
#  363,
#  229,
#  230,
#  231,
#  232,
#  233,
#  234,
#  235,
#  364,
#  368,
#  365,
#  224,
#  405,
#  389,
#  411,
#  339,
#  335,
#  336,
#  333,
#  412,
#  203,
#  206,
#  262,
#  408,
#  388,
#  415,
#  237,
#  238,
#  349,
#  241,
#  399,
#  409,
#  410,
#  416,
#  386,
#  404,
#  373,
#  280,
#  284,
#  282,
#  325,
#  289,
#  278,
#  281]

# %%
counter = len(mec_ranks)
dict_map_eq_centrality = {}

# %%
for node in mec_ranks:
    dict_map_eq_centrality[int(node)] = counter
    counter = counter - 1

# %%
dict_map_eq_centrality
# Out:
# {83: 417,
#  17: 416,
#  2: 415,
#  3: 414,
#  35: 413,
#  30: 412,
#  1: 411,
#  57: 410,
#  5: 409,
#  38: 408,
#  21: 407,
#  52: 406,
#  63: 405,
#  14: 404,
#  10: 403,
#  22: 402,
#  43: 401,
#  12: 400,
#  95: 399,
#  23: 398,
#  112: 397,
#  96: 396,
#  13: 395,
#  7: 394,
#  42: 393,
#  28: 392,
#  26: 391,
#  4: 390,
#  56: 389,
#  54: 388,
#  44: 387,
#  59: 386,
#  73: 385,
#  85: 384,
#  48: 383,
#  47: 382,
#  24: 381,
#  19: 380,
#  70: 379,
#  66: 378,
#  92: 377,
#  8: 376,
#  164: 375,
#  101: 374,
#  20: 373,
#  98: 372,
#  41: 371,
#  106: 370,
#  141: 369,
#  16: 368,
#  50: 367,
#  91: 366,
#  103: 365,
#  124: 364,
#  18: 363,
#  60: 362,
#  114: 361,
#  142: 360,
#  140: 359,
#  39: 358,
#  163: 357,
#  171: 356,
#  111: 355,
#  37: 354,
#  90: 353,
#  102: 352,
#  157: 351,
#  130: 350,
#  40: 349,
#  45: 348,
#  174: 347,
#  75: 346,
#  11: 345,
#  33: 344,
#  167: 343,
#  88: 342,
#  25: 341,
#  97: 340,
#  58: 339,
#  34: 338,
#  15: 337,
#  31: 336,
#  29: 335,
#  67: 334,
#  68: 333,
#  187: 332,
#  170: 331,
#  89: 330,
#  79: 329,
#  105: 328,
#  69: 327,
#  169: 326,
#  236: 325,
#  77: 324,
#  121: 323,
#  126: 322,
#  168: 321,
#  46: 320,
#  36: 319,
#  155: 318,
#  127: 317,
#  84: 316,
#  134: 315,
#  240: 314,
#  80: 313,
#  159: 312,
#  62: 311,
#  86: 310,
#  172: 309,
#  173: 308,
#  154: 307,
#  252: 306,
#  6: 305,
#  322: 304,
#  81: 303,
#  148: 302,
#  27: 301,
#  78: 300,
#  99: 299,
#  49: 298,
#  150: 297,
#  119: 296,
#  71: 295,
#  0: 294,
#  87: 293,
#  246: 292,
#  72: 291,
#  307: 290,
#  53: 289,
#  51: 288,
#  32: 287,
#  61: 286,
#  166: 285,
#  160: 284,
#  115: 283,
#  249: 282,
#  128: 281,
#  109: 280,
#  125: 279,
#  108: 278,
#  323: 277,
#  55: 276,
#  65: 275,
#  182: 274,
#  184: 273,
#  185: 272,
#  122: 271,
#  176: 270,
#  188: 269,
#  244: 268,
#  207: 267,
#  156: 266,
#  178: 265,
#  74: 264,
#  175: 263,
#  165: 262,
#  193: 261,
#  123: 260,
#  190: 259,
#  9: 258,
#  239: 257,
#  158: 256,
#  180: 255,
#  195: 254,
#  250: 253,
#  259: 252,
#  248: 251,
#  104: 250,
#  219: 249,
#  324: 248,
#  329: 247,
#  118: 246,
#  260: 245,
#  153: 244,
#  120: 243,
#  385: 242,
#  379: 241,
#  93: 240,
#  265: 239,
#  147: 238,
#  209: 237,
#  264: 236,
#  181: 235,
#  151: 234,
#  191: 233,
#  261: 232,
#  192: 231,
#  326: 230,
#  107: 229,
#  354: 228,
#  117: 227,
#  351: 226,
#  245: 225,
#  346: 224,
#  258: 223,
#  82: 222,
#  311: 221,
#  312: 220,
#  308: 219,
#  374: 218,
#  131: 217,
#  136: 216,
#  212: 215,
#  217: 214,
#  162: 213,
#  253: 212,
#  143: 211,
#  199: 210,
#  208: 209,
#  149: 208,
#  116: 207,
#  272: 206,
#  76: 205,
#  152: 204,
#  210: 203,
#  391: 202,
#  316: 201,
#  242: 200,
#  383: 199,
#  382: 198,
#  129: 197,
#  135: 196,
#  137: 195,
#  139: 194,
#  247: 193,
#  291: 192,
#  290: 191,
#  285: 190,
#  344: 189,
#  274: 188,
#  255: 187,
#  254: 186,
#  179: 185,
#  197: 184,
#  186: 183,
#  205: 182,
#  269: 181,
#  113: 180,
#  348: 179,
#  342: 178,
#  110: 177,
#  198: 176,
#  144: 175,
#  295: 174,
#  355: 173,
#  392: 172,
#  310: 171,
#  319: 170,
#  396: 169,
#  406: 168,
#  314: 167,
#  376: 166,
#  377: 165,
#  133: 164,
#  138: 163,
#  277: 162,
#  94: 161,
#  225: 160,
#  256: 159,
#  356: 158,
#  352: 157,
#  350: 156,
#  211: 155,
#  337: 154,
#  270: 153,
#  177: 152,
#  201: 151,
#  340: 150,
#  146: 149,
#  296: 148,
#  266: 147,
#  145: 146,
#  400: 145,
#  328: 144,
#  243: 143,
#  395: 142,
#  309: 141,
#  313: 140,
#  320: 139,
#  318: 138,
#  384: 137,
#  381: 136,
#  393: 135,
#  132: 134,
#  273: 133,
#  283: 132,
#  286: 131,
#  361: 130,
#  362: 129,
#  366: 128,
#  372: 127,
#  367: 126,
#  267: 125,
#  271: 124,
#  293: 123,
#  298: 122,
#  300: 121,
#  64: 120,
#  215: 119,
#  327: 118,
#  343: 117,
#  221: 116,
#  228: 115,
#  345: 114,
#  357: 113,
#  360: 112,
#  341: 111,
#  334: 110,
#  332: 109,
#  189: 108,
#  194: 107,
#  196: 106,
#  331: 105,
#  200: 104,
#  202: 103,
#  407: 102,
#  330: 101,
#  403: 100,
#  390: 99,
#  414: 98,
#  397: 97,
#  401: 96,
#  338: 95,
#  347: 94,
#  204: 93,
#  263: 92,
#  398: 91,
#  321: 90,
#  369: 89,
#  370: 88,
#  183: 87,
#  315: 86,
#  375: 85,
#  387: 84,
#  378: 83,
#  380: 82,
#  317: 81,
#  394: 80,
#  276: 79,
#  279: 78,
#  288: 77,
#  287: 76,
#  268: 75,
#  275: 74,
#  251: 73,
#  302: 72,
#  371: 71,
#  301: 70,
#  353: 69,
#  257: 68,
#  402: 67,
#  100: 66,
#  413: 65,
#  297: 64,
#  306: 63,
#  358: 62,
#  294: 61,
#  359: 60,
#  213: 59,
#  214: 58,
#  305: 57,
#  216: 56,
#  304: 55,
#  218: 54,
#  292: 53,
#  220: 52,
#  303: 51,
#  222: 50,
#  223: 49,
#  161: 48,
#  299: 47,
#  226: 46,
#  227: 45,
#  363: 44,
#  229: 43,
#  230: 42,
#  231: 41,
#  232: 40,
#  233: 39,
#  234: 38,
#  235: 37,
#  364: 36,
#  368: 35,
#  365: 34,
#  224: 33,
#  405: 32,
#  389: 31,
#  411: 30,
#  339: 29,
#  335: 28,
#  336: 27,
#  333: 26,
#  412: 25,
#  203: 24,
#  206: 23,
#  262: 22,
#  408: 21,
#  388: 20,
#  415: 19,
#  237: 18,
#  238: 17,
#  349: 16,
#  241: 15,
#  399: 14,
#  409: 13,
#  410: 12,
#  416: 11,
#  386: 10,
#  404: 9,
#  373: 8,
#  280: 7,
#  284: 6,
#  282: 5,
#  325: 4,
#  289: 3,
#  278: 2,
#  281: 1}

# %%
# Write Centrality
with open('./MapEquationCentralityResults/Infra-EUAirlines/dict_map_eq_centrality.txt', 'w') as f:
    for key, value in dict_map_eq_centrality.items():
        f.write('%s:%s\n' % (key, value))

# %%
# Read Centrality
dict_map_eq_centrality_read = dict()
with open('./MapEquationCentralityResults/Infra-EUAirlines/dict_map_eq_centrality.txt') as raw_data:
    for item in raw_data:
        if ':' in item:
            key,value = item.split(':', 1)
            value = value.replace('\n', '')
            dict_map_eq_centrality_read[int(key)]=float(value)
        else:
            pass # deal with bad lines of text here

# %%
dict_map_eq_centrality_read == dict_map_eq_centrality
# Out:
# True
