# %% [markdown]
# # Real-world network

# %%
import networkx as nx
from networkx.algorithms.centrality import *
import numpy as np
import operator
from analysis import *

# %%
g = nx.read_gml("./RealNetworks/e_coli_transcription.gml")

# %%
print(nx.info(g))
# Out:
# Graph with 329 nodes and 456 edges
# <ipython-input-3-99dac2172e06>:1: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   print(nx.info(g))

# %% [markdown]
# # Check connectedness

# %%
nx.is_connected(g)
# Out:
# True

# %%
nx.number_connected_components(g)
# Out:
# 1

# %% [markdown]
# # Get LCC if graph is disconnected

# %% [raw]
# """Step 5: If the graph after immunization is disconnected, get the largest component"""
# g_lcc = nx.Graph()
#
# if nx.is_connected(g) == False:
#     largestComponents = [g.subgraph(c).copy() for c in sorted(nx.connected_components(g), key=len, reverse=True)]
#     print(nx.info(largestComponents[0]))
#
# g_lcc=largestComponents[0]
#
# print(nx.info(g_lcc))
#
# g = g_lcc
#
# print(nx.info(g))

# %% [markdown]
# # Relabel it all if nodes are strings
# - To be able to run all types of correlation together
# - But put the graph relabled in `g_relabled`

# %%
from myTruss import mappingAndRelabeling

# %%
g_relabled = mappingAndRelabeling(g)

# %%
print(nx.info(g))
print(nx.info(g_relabled))
# Out:
# Graph with 329 nodes and 456 edges
# Graph with 329 nodes and 456 edges
# <ipython-input-8-632c4a2d19f6>:1: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   print(nx.info(g))
# <ipython-input-8-632c4a2d19f6>:2: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   print(nx.info(g_relabled))

# %%
g = g_relabled

# %% [markdown]
# # Infer community structure with Louvain

# %%
nx.__version__
# Out:
# '2.8.4'

# %%
import pandas as pd
from os.path  import exists
import infomap as im

# %%
im.__version__
# Out:
# '2.3.0'

# %%
G = g

# %%
partition   = nx.algorithms.community.louvain_communities(G, seed = 0)
partition_Q = nx.algorithms.community.modularity(G, partition)

for seed in Bar("Progress", check_tty = False).iter(range(1,5)):
    partition_   = nx.algorithms.community.louvain_communities(G, seed = seed)
    partition_Q_ = nx.algorithms.community.modularity(G, partition_)
    
    if partition_Q_ > partition_Q:
        partition   = partition_
        partition_Q = partition_Q_
# Out:
# Progress |################################| 4/4

# %%
communities = { community_ID : set(community) for (community_ID, community) in enumerate(partition, start = 1)}

# %%
community_assignments = dict()
for (community_ID, community) in communities.items():
    for node in community:
        community_assignments[node] = community_ID

# %%
results_file = "./results/e_coli_transcription-modularity.csv"

if not exists(results_file):
    # Map Equation Centrality
    tree_file = "./results/e_coli_transcription-temp.tree"

    # use Infomap to write a tree file that we change to reflect the Louvain partition
    infomap = im.Infomap(silent = True, num_trials = 1, directed = False, two_level = True, seed = 42)
    infomap.add_networkx_graph(G)
    infomap.run()
    infomap.write_tree(tree_file)
    
    infomap_tree = dict()

    # read the tree file
    with open(tree_file, "r") as fh:
        for line in fh:
            if not line.startswith("#"):
                _, flow, name, node_id = line.strip().split(" ")
                name = name[1:-1]
                infomap_tree[int(name)] = (flow, node_id)
    
    # write the Louvain partition to an Infomap tree file
    with open("./results/e_coli_transcription-modularity.tree", "w") as fh:
        for community_ID, community in enumerate(partition, start = 1):
            for node_pos, node in enumerate(community, start = 1):
                path = f"{community_ID}:{node_pos}"
                flow, node_id = infomap_tree[node]
                fh.write(f"{path} {flow} \"{node}\" {node_id}\n")
    
    # Load the Louvain partition with Infomap and use unrecorded link teleportation
    infomap2 = im.Infomap("--silent --no-infomap --cluster-data ./results/e_coli_transcription-modularity.tree")
    node_mapping = infomap2.add_networkx_graph(G)
    infomap2.run()
    
    mec_ranks = [node for node, _score in sorted( [ (node_mapping[node.node_id], node.modular_centrality) for node in infomap2.iterLeafNodes() ]
                                                 , key     = second
                                                 , reverse = True
                                                 )]

    
    index = []
    for node in G.nodes:
        index.append(node)

    results = pd.DataFrame(index=index)

    results["map equation centrality rank"]       = toRanking(mec_ranks,        results.index)
    results.to_csv(results_file)

else:
    results = pd.read_csv(results_file, index_col = 0)

    mec_ranks         = mkRanks(results["map equation centrality rank"])

# %%
len(mec_ranks)
# Out:
# 329

# %%
# node 107 has rank 0 (i.e. 1)
# node 1684 has rank 1 (i.e. 2)
# ...
# node 0 has rank 4 (i.e. 5)
mec_ranks
# Out:
# [52,
#  151,
#  264,
#  181,
#  10,
#  305,
#  239,
#  196,
#  142,
#  230,
#  226,
#  294,
#  101,
#  257,
#  66,
#  42,
#  117,
#  69,
#  86,
#  185,
#  160,
#  118,
#  300,
#  39,
#  210,
#  27,
#  5,
#  17,
#  126,
#  105,
#  129,
#  28,
#  92,
#  221,
#  178,
#  15,
#  21,
#  26,
#  60,
#  127,
#  135,
#  177,
#  74,
#  11,
#  161,
#  235,
#  53,
#  19,
#  214,
#  218,
#  173,
#  179,
#  98,
#  88,
#  40,
#  71,
#  70,
#  3,
#  328,
#  23,
#  156,
#  157,
#  155,
#  189,
#  137,
#  138,
#  20,
#  35,
#  176,
#  187,
#  131,
#  65,
#  97,
#  54,
#  182,
#  188,
#  94,
#  107,
#  120,
#  61,
#  212,
#  213,
#  102,
#  256,
#  6,
#  7,
#  8,
#  9,
#  41,
#  171,
#  93,
#  85,
#  99,
#  100,
#  110,
#  62,
#  63,
#  112,
#  67,
#  68,
#  75,
#  76,
#  77,
#  78,
#  79,
#  81,
#  83,
#  82,
#  84,
#  87,
#  89,
#  90,
#  91,
#  4,
#  12,
#  13,
#  14,
#  22,
#  153,
#  154,
#  159,
#  228,
#  55,
#  140,
#  141,
#  143,
#  144,
#  145,
#  113,
#  114,
#  115,
#  191,
#  125,
#  136,
#  297,
#  192,
#  194,
#  206,
#  0,
#  2,
#  16,
#  231,
#  232,
#  254,
#  45,
#  46,
#  47,
#  49,
#  50,
#  51,
#  96,
#  109,
#  121,
#  122,
#  215,
#  219,
#  211,
#  133,
#  56,
#  34,
#  304,
#  180,
#  57,
#  58,
#  59,
#  64,
#  208,
#  95,
#  327,
#  225,
#  195,
#  80,
#  209,
#  222,
#  103,
#  104,
#  106,
#  108,
#  72,
#  111,
#  73,
#  123,
#  124,
#  18,
#  24,
#  158,
#  152,
#  227,
#  38,
#  303,
#  25,
#  139,
#  146,
#  147,
#  148,
#  149,
#  150,
#  197,
#  198,
#  199,
#  200,
#  201,
#  202,
#  203,
#  204,
#  205,
#  116,
#  190,
#  128,
#  36,
#  37,
#  295,
#  296,
#  298,
#  302,
#  175,
#  183,
#  184,
#  186,
#  193,
#  207,
#  223,
#  224,
#  238,
#  1,
#  130,
#  132,
#  162,
#  163,
#  229,
#  233,
#  234,
#  236,
#  237,
#  164,
#  255,
#  265,
#  266,
#  267,
#  268,
#  269,
#  270,
#  271,
#  272,
#  273,
#  274,
#  275,
#  276,
#  277,
#  278,
#  279,
#  280,
#  281,
#  282,
#  283,
#  43,
#  44,
#  48,
#  284,
#  285,
#  286,
#  287,
#  288,
#  289,
#  290,
#  291,
#  292,
#  293,
#  119,
#  216,
#  217,
#  220,
#  172,
#  174,
#  240,
#  241,
#  242,
#  243,
#  244,
#  245,
#  246,
#  247,
#  248,
#  249,
#  250,
#  251,
#  252,
#  253,
#  258,
#  259,
#  260,
#  261,
#  262,
#  263,
#  299,
#  301,
#  320,
#  321,
#  322,
#  323,
#  324,
#  325,
#  326,
#  306,
#  307,
#  308,
#  309,
#  310,
#  311,
#  312,
#  313,
#  314,
#  315,
#  316,
#  317,
#  318,
#  319,
#  134,
#  165,
#  169,
#  167,
#  168,
#  166,
#  170,
#  32,
#  33,
#  29,
#  30,
#  31]

# %%
counter = len(mec_ranks)
dict_map_eq_centrality = {}

# %%
for node in mec_ranks:
    dict_map_eq_centrality[int(node)] = counter
    counter = counter - 1

# %%
dict_map_eq_centrality
# Out:
# {52: 329,
#  151: 328,
#  264: 327,
#  181: 326,
#  10: 325,
#  305: 324,
#  239: 323,
#  196: 322,
#  142: 321,
#  230: 320,
#  226: 319,
#  294: 318,
#  101: 317,
#  257: 316,
#  66: 315,
#  42: 314,
#  117: 313,
#  69: 312,
#  86: 311,
#  185: 310,
#  160: 309,
#  118: 308,
#  300: 307,
#  39: 306,
#  210: 305,
#  27: 304,
#  5: 303,
#  17: 302,
#  126: 301,
#  105: 300,
#  129: 299,
#  28: 298,
#  92: 297,
#  221: 296,
#  178: 295,
#  15: 294,
#  21: 293,
#  26: 292,
#  60: 291,
#  127: 290,
#  135: 289,
#  177: 288,
#  74: 287,
#  11: 286,
#  161: 285,
#  235: 284,
#  53: 283,
#  19: 282,
#  214: 281,
#  218: 280,
#  173: 279,
#  179: 278,
#  98: 277,
#  88: 276,
#  40: 275,
#  71: 274,
#  70: 273,
#  3: 272,
#  328: 271,
#  23: 270,
#  156: 269,
#  157: 268,
#  155: 267,
#  189: 266,
#  137: 265,
#  138: 264,
#  20: 263,
#  35: 262,
#  176: 261,
#  187: 260,
#  131: 259,
#  65: 258,
#  97: 257,
#  54: 256,
#  182: 255,
#  188: 254,
#  94: 253,
#  107: 252,
#  120: 251,
#  61: 250,
#  212: 249,
#  213: 248,
#  102: 247,
#  256: 246,
#  6: 245,
#  7: 244,
#  8: 243,
#  9: 242,
#  41: 241,
#  171: 240,
#  93: 239,
#  85: 238,
#  99: 237,
#  100: 236,
#  110: 235,
#  62: 234,
#  63: 233,
#  112: 232,
#  67: 231,
#  68: 230,
#  75: 229,
#  76: 228,
#  77: 227,
#  78: 226,
#  79: 225,
#  81: 224,
#  83: 223,
#  82: 222,
#  84: 221,
#  87: 220,
#  89: 219,
#  90: 218,
#  91: 217,
#  4: 216,
#  12: 215,
#  13: 214,
#  14: 213,
#  22: 212,
#  153: 211,
#  154: 210,
#  159: 209,
#  228: 208,
#  55: 207,
#  140: 206,
#  141: 205,
#  143: 204,
#  144: 203,
#  145: 202,
#  113: 201,
#  114: 200,
#  115: 199,
#  191: 198,
#  125: 197,
#  136: 196,
#  297: 195,
#  192: 194,
#  194: 193,
#  206: 192,
#  0: 191,
#  2: 190,
#  16: 189,
#  231: 188,
#  232: 187,
#  254: 186,
#  45: 185,
#  46: 184,
#  47: 183,
#  49: 182,
#  50: 181,
#  51: 180,
#  96: 179,
#  109: 178,
#  121: 177,
#  122: 176,
#  215: 175,
#  219: 174,
#  211: 173,
#  133: 172,
#  56: 171,
#  34: 170,
#  304: 169,
#  180: 168,
#  57: 167,
#  58: 166,
#  59: 165,
#  64: 164,
#  208: 163,
#  95: 162,
#  327: 161,
#  225: 160,
#  195: 159,
#  80: 158,
#  209: 157,
#  222: 156,
#  103: 155,
#  104: 154,
#  106: 153,
#  108: 152,
#  72: 151,
#  111: 150,
#  73: 149,
#  123: 148,
#  124: 147,
#  18: 146,
#  24: 145,
#  158: 144,
#  152: 143,
#  227: 142,
#  38: 141,
#  303: 140,
#  25: 139,
#  139: 138,
#  146: 137,
#  147: 136,
#  148: 135,
#  149: 134,
#  150: 133,
#  197: 132,
#  198: 131,
#  199: 130,
#  200: 129,
#  201: 128,
#  202: 127,
#  203: 126,
#  204: 125,
#  205: 124,
#  116: 123,
#  190: 122,
#  128: 121,
#  36: 120,
#  37: 119,
#  295: 118,
#  296: 117,
#  298: 116,
#  302: 115,
#  175: 114,
#  183: 113,
#  184: 112,
#  186: 111,
#  193: 110,
#  207: 109,
#  223: 108,
#  224: 107,
#  238: 106,
#  1: 105,
#  130: 104,
#  132: 103,
#  162: 102,
#  163: 101,
#  229: 100,
#  233: 99,
#  234: 98,
#  236: 97,
#  237: 96,
#  164: 95,
#  255: 94,
#  265: 93,
#  266: 92,
#  267: 91,
#  268: 90,
#  269: 89,
#  270: 88,
#  271: 87,
#  272: 86,
#  273: 85,
#  274: 84,
#  275: 83,
#  276: 82,
#  277: 81,
#  278: 80,
#  279: 79,
#  280: 78,
#  281: 77,
#  282: 76,
#  283: 75,
#  43: 74,
#  44: 73,
#  48: 72,
#  284: 71,
#  285: 70,
#  286: 69,
#  287: 68,
#  288: 67,
#  289: 66,
#  290: 65,
#  291: 64,
#  292: 63,
#  293: 62,
#  119: 61,
#  216: 60,
#  217: 59,
#  220: 58,
#  172: 57,
#  174: 56,
#  240: 55,
#  241: 54,
#  242: 53,
#  243: 52,
#  244: 51,
#  245: 50,
#  246: 49,
#  247: 48,
#  248: 47,
#  249: 46,
#  250: 45,
#  251: 44,
#  252: 43,
#  253: 42,
#  258: 41,
#  259: 40,
#  260: 39,
#  261: 38,
#  262: 37,
#  263: 36,
#  299: 35,
#  301: 34,
#  320: 33,
#  321: 32,
#  322: 31,
#  323: 30,
#  324: 29,
#  325: 28,
#  326: 27,
#  306: 26,
#  307: 25,
#  308: 24,
#  309: 23,
#  310: 22,
#  311: 21,
#  312: 20,
#  313: 19,
#  314: 18,
#  315: 17,
#  316: 16,
#  317: 15,
#  318: 14,
#  319: 13,
#  134: 12,
#  165: 11,
#  169: 10,
#  167: 9,
#  168: 8,
#  166: 7,
#  170: 6,
#  32: 5,
#  33: 4,
#  29: 3,
#  30: 2,
#  31: 1}

# %%
# Write Centrality
with open('./MapEquationCentralityResults/Bio-EColi/dict_map_eq_centrality.txt', 'w') as f:
    for key, value in dict_map_eq_centrality.items():
        f.write('%s:%s\n' % (key, value))

# %%
# Read Centrality
dict_map_eq_centrality_read = dict()
with open('./MapEquationCentralityResults/Bio-EColi/dict_map_eq_centrality.txt') as raw_data:
    for item in raw_data:
        if ':' in item:
            key,value = item.split(':', 1)
            value = value.replace('\n', '')
            dict_map_eq_centrality_read[int(key)]=float(value)
        else:
            pass # deal with bad lines of text here

# %%
dict_map_eq_centrality_read == dict_map_eq_centrality
# Out:
# True
