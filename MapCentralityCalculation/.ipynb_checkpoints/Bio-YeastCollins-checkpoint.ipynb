# %% [markdown]
# # Real-world network

# %%
import networkx as nx
from networkx.algorithms.centrality import *
import numpy as np
import operator
from analysis import *

# %%
g = nx.read_gml("./RealNetworks/yeast_collins.gml")

# %%
print(nx.info(g))
# Out:
# Graph with 1004 nodes and 8319 edges
# <ipython-input-3-99dac2172e06>:1: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   print(nx.info(g))

# %% [markdown]
# # Check connectedness

# %%
nx.is_connected(g)
# Out:
# True

# %%
nx.number_connected_components(g)
# Out:
# 1

# %% [markdown]
# # Get LCC if graph is disconnected

# %% [raw]
# """Step 5: If the graph after immunization is disconnected, get the largest component"""
# g_lcc = nx.Graph()
#
# if nx.is_connected(g) == False:
#     largestComponents = [g.subgraph(c).copy() for c in sorted(nx.connected_components(g), key=len, reverse=True)]
#     print(nx.info(largestComponents[0]))
#
# g_lcc=largestComponents[0]
#
# print(nx.info(g_lcc))
#
# g = g_lcc
#
# print(nx.info(g))

# %% [markdown]
# # Relabel it all if nodes are strings
# - To be able to run all types of correlation together
# - But put the graph relabled in `g_relabled`

# %%
from myTruss import mappingAndRelabeling

# %%
g_relabled = mappingAndRelabeling(g)

# %%
print(nx.info(g))
print(nx.info(g_relabled))
# Out:
# Graph with 1004 nodes and 8319 edges
# Graph with 1004 nodes and 8319 edges
# <ipython-input-8-632c4a2d19f6>:1: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   print(nx.info(g))
# <ipython-input-8-632c4a2d19f6>:2: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   print(nx.info(g_relabled))

# %%
g = g_relabled

# %% [markdown]
# # Infer community structure with Louvain

# %%
nx.__version__
# Out:
# '2.8.4'

# %%
import pandas as pd
from os.path  import exists
import infomap as im

# %%
im.__version__
# Out:
# '2.3.0'

# %%
G = g

# %%
partition   = nx.algorithms.community.louvain_communities(G, seed = 0)
partition_Q = nx.algorithms.community.modularity(G, partition)

for seed in Bar("Progress", check_tty = False).iter(range(1,5)):
    partition_   = nx.algorithms.community.louvain_communities(G, seed = seed)
    partition_Q_ = nx.algorithms.community.modularity(G, partition_)
    
    if partition_Q_ > partition_Q:
        partition   = partition_
        partition_Q = partition_Q_
# Out:
# Progress |################################| 4/4

# %%
communities = { community_ID : set(community) for (community_ID, community) in enumerate(partition, start = 1)}

# %%
community_assignments = dict()
for (community_ID, community) in communities.items():
    for node in community:
        community_assignments[node] = community_ID

# %%
results_file = "./results/yeast_collins-modularity.csv"

if not exists(results_file):
    # Map Equation Centrality
    tree_file = "./results/yeast_collins-temp.tree"

    # use Infomap to write a tree file that we change to reflect the Louvain partition
    infomap = im.Infomap(silent = True, num_trials = 1, directed = False, two_level = True, seed = 42)
    infomap.add_networkx_graph(G)
    infomap.run()
    infomap.write_tree(tree_file)
    
    infomap_tree = dict()

    # read the tree file
    with open(tree_file, "r") as fh:
        for line in fh:
            if not line.startswith("#"):
                _, flow, name, node_id = line.strip().split(" ")
                name = name[1:-1]
                infomap_tree[int(name)] = (flow, node_id)
    
    # write the Louvain partition to an Infomap tree file
    with open("./results/yeast_collins-modularity.tree", "w") as fh:
        for community_ID, community in enumerate(partition, start = 1):
            for node_pos, node in enumerate(community, start = 1):
                path = f"{community_ID}:{node_pos}"
                flow, node_id = infomap_tree[node]
                fh.write(f"{path} {flow} \"{node}\" {node_id}\n")
    
    # Load the Louvain partition with Infomap and use unrecorded link teleportation
    infomap2 = im.Infomap("--silent --no-infomap --cluster-data ./results/yeast_collins-modularity.tree")
    node_mapping = infomap2.add_networkx_graph(G)
    infomap2.run()
    
    mec_ranks = [node for node, _score in sorted( [ (node_mapping[node.node_id], node.modular_centrality) for node in infomap2.iterLeafNodes() ]
                                                 , key     = second
                                                 , reverse = True
                                                 )]

    
    index = []
    for node in G.nodes:
        index.append(node)

    results = pd.DataFrame(index=index)

    results["map equation centrality rank"]       = toRanking(mec_ranks,        results.index)
    results.to_csv(results_file)

else:
    results = pd.read_csv(results_file, index_col = 0)

    mec_ranks         = mkRanks(results["map equation centrality rank"])

# %%
len(mec_ranks)
# Out:
# 1004

# %%
# node 107 has rank 0 (i.e. 1)
# node 1684 has rank 1 (i.e. 2)
# ...
# node 0 has rank 4 (i.e. 5)
mec_ranks
# Out:
# [146,
#  197,
#  204,
#  198,
#  141,
#  171,
#  188,
#  120,
#  181,
#  186,
#  386,
#  167,
#  189,
#  163,
#  130,
#  162,
#  140,
#  185,
#  136,
#  190,
#  157,
#  184,
#  148,
#  165,
#  139,
#  150,
#  187,
#  178,
#  179,
#  153,
#  177,
#  129,
#  127,
#  138,
#  155,
#  164,
#  137,
#  168,
#  145,
#  175,
#  182,
#  193,
#  170,
#  156,
#  135,
#  14,
#  123,
#  199,
#  158,
#  257,
#  152,
#  169,
#  172,
#  203,
#  173,
#  446,
#  161,
#  194,
#  132,
#  261,
#  134,
#  83,
#  159,
#  191,
#  176,
#  201,
#  274,
#  160,
#  85,
#  174,
#  235,
#  183,
#  195,
#  426,
#  200,
#  265,
#  80,
#  229,
#  260,
#  202,
#  222,
#  447,
#  251,
#  103,
#  385,
#  252,
#  237,
#  104,
#  286,
#  88,
#  798,
#  224,
#  246,
#  96,
#  216,
#  232,
#  154,
#  276,
#  210,
#  228,
#  239,
#  180,
#  267,
#  111,
#  420,
#  214,
#  211,
#  270,
#  277,
#  219,
#  242,
#  166,
#  98,
#  240,
#  253,
#  534,
#  712,
#  256,
#  263,
#  273,
#  266,
#  233,
#  226,
#  554,
#  433,
#  90,
#  213,
#  533,
#  389,
#  262,
#  92,
#  110,
#  215,
#  24,
#  245,
#  94,
#  100,
#  734,
#  254,
#  275,
#  234,
#  250,
#  109,
#  218,
#  259,
#  244,
#  425,
#  264,
#  221,
#  225,
#  505,
#  812,
#  39,
#  556,
#  599,
#  394,
#  664,
#  151,
#  91,
#  106,
#  105,
#  87,
#  813,
#  17,
#  20,
#  580,
#  564,
#  595,
#  610,
#  247,
#  452,
#  419,
#  387,
#  217,
#  524,
#  520,
#  496,
#  576,
#  560,
#  561,
#  569,
#  570,
#  571,
#  593,
#  605,
#  487,
#  399,
#  269,
#  422,
#  86,
#  230,
#  241,
#  510,
#  512,
#  532,
#  555,
#  565,
#  568,
#  572,
#  596,
#  602,
#  619,
#  473,
#  474,
#  475,
#  483,
#  488,
#  388,
#  231,
#  521,
#  511,
#  811,
#  814,
#  517,
#  519,
#  23,
#  578,
#  557,
#  562,
#  563,
#  575,
#  586,
#  587,
#  591,
#  597,
#  600,
#  601,
#  603,
#  606,
#  470,
#  472,
#  272,
#  107,
#  424,
#  93,
#  97,
#  523,
#  518,
#  525,
#  574,
#  589,
#  590,
#  598,
#  604,
#  607,
#  608,
#  609,
#  620,
#  376,
#  126,
#  485,
#  300,
#  280,
#  646,
#  271,
#  707,
#  77,
#  102,
#  223,
#  514,
#  516,
#  730,
#  566,
#  567,
#  573,
#  594,
#  468,
#  469,
#  471,
#  484,
#  486,
#  657,
#  659,
#  667,
#  672,
#  297,
#  427,
#  421,
#  513,
#  815,
#  738,
#  22,
#  579,
#  585,
#  588,
#  592,
#  378,
#  362,
#  353,
#  478,
#  479,
#  480,
#  481,
#  656,
#  660,
#  124,
#  196,
#  342,
#  95,
#  101,
#  79,
#  81,
#  391,
#  212,
#  292,
#  515,
#  816,
#  357,
#  476,
#  661,
#  663,
#  665,
#  395,
#  258,
#  114,
#  700,
#  227,
#  384,
#  714,
#  577,
#  477,
#  278,
#  396,
#  766,
#  112,
#  699,
#  522,
#  495,
#  25,
#  42,
#  380,
#  381,
#  356,
#  482,
#  675,
#  128,
#  708,
#  709,
#  89,
#  76,
#  437,
#  701,
#  702,
#  506,
#  531,
#  723,
#  720,
#  722,
#  719,
#  737,
#  559,
#  347,
#  668,
#  673,
#  298,
#  287,
#  448,
#  249,
#  767,
#  108,
#  529,
#  725,
#  718,
#  733,
#  383,
#  615,
#  374,
#  379,
#  658,
#  662,
#  295,
#  370,
#  288,
#  282,
#  208,
#  435,
#  434,
#  393,
#  494,
#  497,
#  729,
#  715,
#  731,
#  739,
#  617,
#  823,
#  618,
#  614,
#  490,
#  666,
#  670,
#  294,
#  302,
#  304,
#  283,
#  542,
#  143,
#  144,
#  414,
#  285,
#  323,
#  438,
#  498,
#  500,
#  501,
#  502,
#  503,
#  504,
#  508,
#  509,
#  499,
#  728,
#  724,
#  58,
#  616,
#  671,
#  674,
#  296,
#  299,
#  303,
#  306,
#  307,
#  326,
#  324,
#  327,
#  826,
#  829,
#  325,
#  831,
#  799,
#  838,
#  82,
#  423,
#  428,
#  236,
#  507,
#  713,
#  735,
#  46,
#  931,
#  41,
#  360,
#  491,
#  466,
#  5,
#  669,
#  309,
#  301,
#  305,
#  328,
#  825,
#  828,
#  827,
#  830,
#  205,
#  773,
#  350,
#  369,
#  255,
#  99,
#  408,
#  736,
#  727,
#  721,
#  732,
#  716,
#  16,
#  18,
#  29,
#  32,
#  930,
#  929,
#  37,
#  844,
#  34,
#  832,
#  440,
#  456,
#  462,
#  797,
#  429,
#  404,
#  238,
#  810,
#  726,
#  717,
#  44,
#  68,
#  30,
#  48,
#  49,
#  50,
#  51,
#  73,
#  35,
#  784,
#  38,
#  12,
#  119,
#  633,
#  8,
#  147,
#  149,
#  774,
#  289,
#  192,
#  78,
#  837,
#  21,
#  47,
#  40,
#  349,
#  786,
#  346,
#  377,
#  779,
#  492,
#  676,
#  118,
#  122,
#  704,
#  133,
#  206,
#  142,
#  772,
#  775,
#  368,
#  754,
#  341,
#  243,
#  549,
#  431,
#  407,
#  60,
#  45,
#  27,
#  28,
#  43,
#  52,
#  751,
#  783,
#  785,
#  354,
#  355,
#  780,
#  932,
#  13,
#  644,
#  808,
#  209,
#  776,
#  371,
#  753,
#  755,
#  756,
#  757,
#  759,
#  760,
#  761,
#  762,
#  284,
#  397,
#  248,
#  432,
#  36,
#  15,
#  53,
#  782,
#  787,
#  363,
#  489,
#  882,
#  636,
#  643,
#  336,
#  338,
#  959,
#  539,
#  852,
#  544,
#  913,
#  758,
#  290,
#  281,
#  467,
#  455,
#  465,
#  652,
#  84,
#  411,
#  741,
#  19,
#  57,
#  582,
#  358,
#  345,
#  361,
#  463,
#  879,
#  919,
#  918,
#  11,
#  634,
#  654,
#  878,
#  884,
#  748,
#  873,
#  677,
#  679,
#  329,
#  317,
#  316,
#  685,
#  538,
#  543,
#  545,
#  131,
#  647,
#  648,
#  650,
#  651,
#  207,
#  681,
#  454,
#  268,
#  976,
#  550,
#  293,
#  839,
#  764,
#  436,
#  115,
#  220,
#  392,
#  412,
#  26,
#  65,
#  769,
#  364,
#  626,
#  628,
#  629,
#  4,
#  630,
#  881,
#  635,
#  883,
#  0,
#  640,
#  921,
#  922,
#  885,
#  924,
#  624,
#  896,
#  898,
#  331,
#  310,
#  332,
#  333,
#  540,
#  853,
#  854,
#  855,
#  856,
#  857,
#  858,
#  788,
#  703,
#  778,
#  409,
#  458,
#  445,
#  279,
#  405,
#  820,
#  821,
#  818,
#  817,
#  819,
#  845,
#  977,
#  72,
#  800,
#  801,
#  63,
#  443,
#  439,
#  581,
#  583,
#  558,
#  348,
#  621,
#  791,
#  805,
#  920,
#  6,
#  872,
#  641,
#  886,
#  874,
#  623,
#  637,
#  897,
#  308,
#  895,
#  688,
#  686,
#  689,
#  334,
#  833,
#  546,
#  888,
#  951,
#  692,
#  694,
#  695,
#  696,
#  451,
#  449,
#  402,
#  430,
#  541,
#  406,
#  400,
#  398,
#  413,
#  530,
#  967,
#  33,
#  61,
#  970,
#  59,
#  352,
#  770,
#  781,
#  2,
#  3,
#  875,
#  908,
#  536,
#  537,
#  809,
#  55,
#  880,
#  631,
#  946,
#  632,
#  639,
#  645,
#  923,
#  903,
#  638,
#  747,
#  678,
#  312,
#  318,
#  330,
#  899,
#  937,
#  916,
#  864,
#  866,
#  867,
#  401,
#  687,
#  690,
#  320,
#  337,
#  121,
#  790,
#  745,
#  777,
#  958,
#  693,
#  7,
#  459,
#  373,
#  403,
#  291,
#  551,
#  940,
#  763,
#  113,
#  683,
#  442,
#  796,
#  416,
#  891,
#  528,
#  527,
#  74,
#  803,
#  62,
#  945,
#  71,
#  611,
#  752,
#  768,
#  375,
#  359,
#  771,
#  351,
#  493,
#  907,
#  806,
#  807,
#  56,
#  876,
#  904,
#  613,
#  947,
#  917,
#  865,
#  868,
#  869,
#  893,
#  339,
#  964,
#  441,
#  824,
#  319,
#  322,
#  890,
#  889,
#  925,
#  910,
#  927,
#  680,
#  343,
#  979,
#  765,
#  553,
#  986,
#  552,
#  960,
#  684,
#  991,
#  410,
#  390,
#  418,
#  417,
#  822,
#  846,
#  835,
#  742,
#  834,
#  31,
#  64,
#  804,
#  939,
#  944,
#  70,
#  697,
#  968,
#  969,
#  802,
#  981,
#  584,
#  793,
#  367,
#  366,
#  794,
#  996,
#  642,
#  653,
#  901,
#  933,
#  934,
#  943,
#  949,
#  750,
#  963,
#  948,
#  992,
#  10,
#  535,
#  749,
#  900,
#  840,
#  911,
#  870,
#  892,
#  965,
#  706,
#  335,
#  887,
#  950,
#  321,
#  789,
#  744,
#  710,
#  311,
#  952,
#  955,
#  956,
#  957,
#  849,
#  850,
#  980,
#  450,
#  926,
#  994,
#  998,
#  460,
#  746,
#  464,
#  461,
#  457,
#  861,
#  860,
#  344,
#  453,
#  848,
#  993,
#  847,
#  444,
#  116,
#  682,
#  548,
#  547,
#  978,
#  987,
#  975,
#  415,
#  795,
#  974,
#  526,
#  936,
#  842,
#  985,
#  894,
#  740,
#  912,
#  75,
#  836,
#  938,
#  859,
#  69,
#  67,
#  66,
#  971,
#  984,
#  989,
#  999,
#  1002,
#  1003,
#  365,
#  372,
#  622,
#  915,
#  382,
#  705,
#  914,
#  935,
#  941,
#  942,
#  625,
#  862,
#  1,
#  54,
#  877,
#  698,
#  961,
#  906,
#  905,
#  966,
#  972,
#  9,
#  627,
#  988,
#  612,
#  997,
#  1000,
#  1001,
#  655,
#  863,
#  909,
#  962,
#  314,
#  315,
#  928,
#  340,
#  313,
#  871,
#  841,
#  843,
#  691,
#  117,
#  902,
#  125,
#  792,
#  973,
#  990,
#  743,
#  649,
#  711,
#  982,
#  983,
#  ...]

# %%
counter = len(mec_ranks)
dict_map_eq_centrality = {}

# %%
for node in mec_ranks:
    dict_map_eq_centrality[int(node)] = counter
    counter = counter - 1

# %%
dict_map_eq_centrality
# Out:
# {146: 1004,
#  197: 1003,
#  204: 1002,
#  198: 1001,
#  141: 1000,
#  171: 999,
#  188: 998,
#  120: 997,
#  181: 996,
#  186: 995,
#  386: 994,
#  167: 993,
#  189: 992,
#  163: 991,
#  130: 990,
#  162: 989,
#  140: 988,
#  185: 987,
#  136: 986,
#  190: 985,
#  157: 984,
#  184: 983,
#  148: 982,
#  165: 981,
#  139: 980,
#  150: 979,
#  187: 978,
#  178: 977,
#  179: 976,
#  153: 975,
#  177: 974,
#  129: 973,
#  127: 972,
#  138: 971,
#  155: 970,
#  164: 969,
#  137: 968,
#  168: 967,
#  145: 966,
#  175: 965,
#  182: 964,
#  193: 963,
#  170: 962,
#  156: 961,
#  135: 960,
#  14: 959,
#  123: 958,
#  199: 957,
#  158: 956,
#  257: 955,
#  152: 954,
#  169: 953,
#  172: 952,
#  203: 951,
#  173: 950,
#  446: 949,
#  161: 948,
#  194: 947,
#  132: 946,
#  261: 945,
#  134: 944,
#  83: 943,
#  159: 942,
#  191: 941,
#  176: 940,
#  201: 939,
#  274: 938,
#  160: 937,
#  85: 936,
#  174: 935,
#  235: 934,
#  183: 933,
#  195: 932,
#  426: 931,
#  200: 930,
#  265: 929,
#  80: 928,
#  229: 927,
#  260: 926,
#  202: 925,
#  222: 924,
#  447: 923,
#  251: 922,
#  103: 921,
#  385: 920,
#  252: 919,
#  237: 918,
#  104: 917,
#  286: 916,
#  88: 915,
#  798: 914,
#  224: 913,
#  246: 912,
#  96: 911,
#  216: 910,
#  232: 909,
#  154: 908,
#  276: 907,
#  210: 906,
#  228: 905,
#  239: 904,
#  180: 903,
#  267: 902,
#  111: 901,
#  420: 900,
#  214: 899,
#  211: 898,
#  270: 897,
#  277: 896,
#  219: 895,
#  242: 894,
#  166: 893,
#  98: 892,
#  240: 891,
#  253: 890,
#  534: 889,
#  712: 888,
#  256: 887,
#  263: 886,
#  273: 885,
#  266: 884,
#  233: 883,
#  226: 882,
#  554: 881,
#  433: 880,
#  90: 879,
#  213: 878,
#  533: 877,
#  389: 876,
#  262: 875,
#  92: 874,
#  110: 873,
#  215: 872,
#  24: 871,
#  245: 870,
#  94: 869,
#  100: 868,
#  734: 867,
#  254: 866,
#  275: 865,
#  234: 864,
#  250: 863,
#  109: 862,
#  218: 861,
#  259: 860,
#  244: 859,
#  425: 858,
#  264: 857,
#  221: 856,
#  225: 855,
#  505: 854,
#  812: 853,
#  39: 852,
#  556: 851,
#  599: 850,
#  394: 849,
#  664: 848,
#  151: 847,
#  91: 846,
#  106: 845,
#  105: 844,
#  87: 843,
#  813: 842,
#  17: 841,
#  20: 840,
#  580: 839,
#  564: 838,
#  595: 837,
#  610: 836,
#  247: 835,
#  452: 834,
#  419: 833,
#  387: 832,
#  217: 831,
#  524: 830,
#  520: 829,
#  496: 828,
#  576: 827,
#  560: 826,
#  561: 825,
#  569: 824,
#  570: 823,
#  571: 822,
#  593: 821,
#  605: 820,
#  487: 819,
#  399: 818,
#  269: 817,
#  422: 816,
#  86: 815,
#  230: 814,
#  241: 813,
#  510: 812,
#  512: 811,
#  532: 810,
#  555: 809,
#  565: 808,
#  568: 807,
#  572: 806,
#  596: 805,
#  602: 804,
#  619: 803,
#  473: 802,
#  474: 801,
#  475: 800,
#  483: 799,
#  488: 798,
#  388: 797,
#  231: 796,
#  521: 795,
#  511: 794,
#  811: 793,
#  814: 792,
#  517: 791,
#  519: 790,
#  23: 789,
#  578: 788,
#  557: 787,
#  562: 786,
#  563: 785,
#  575: 784,
#  586: 783,
#  587: 782,
#  591: 781,
#  597: 780,
#  600: 779,
#  601: 778,
#  603: 777,
#  606: 776,
#  470: 775,
#  472: 774,
#  272: 773,
#  107: 772,
#  424: 771,
#  93: 770,
#  97: 769,
#  523: 768,
#  518: 767,
#  525: 766,
#  574: 765,
#  589: 764,
#  590: 763,
#  598: 762,
#  604: 761,
#  607: 760,
#  608: 759,
#  609: 758,
#  620: 757,
#  376: 756,
#  126: 755,
#  485: 754,
#  300: 753,
#  280: 752,
#  646: 751,
#  271: 750,
#  707: 749,
#  77: 748,
#  102: 747,
#  223: 746,
#  514: 745,
#  516: 744,
#  730: 743,
#  566: 742,
#  567: 741,
#  573: 740,
#  594: 739,
#  468: 738,
#  469: 737,
#  471: 736,
#  484: 735,
#  486: 734,
#  657: 733,
#  659: 732,
#  667: 731,
#  672: 730,
#  297: 729,
#  427: 728,
#  421: 727,
#  513: 726,
#  815: 725,
#  738: 724,
#  22: 723,
#  579: 722,
#  585: 721,
#  588: 720,
#  592: 719,
#  378: 718,
#  362: 717,
#  353: 716,
#  478: 715,
#  479: 714,
#  480: 713,
#  481: 712,
#  656: 711,
#  660: 710,
#  124: 709,
#  196: 708,
#  342: 707,
#  95: 706,
#  101: 705,
#  79: 704,
#  81: 703,
#  391: 702,
#  212: 701,
#  292: 700,
#  515: 699,
#  816: 698,
#  357: 697,
#  476: 696,
#  661: 695,
#  663: 694,
#  665: 693,
#  395: 692,
#  258: 691,
#  114: 690,
#  700: 689,
#  227: 688,
#  384: 687,
#  714: 686,
#  577: 685,
#  477: 684,
#  278: 683,
#  396: 682,
#  766: 681,
#  112: 680,
#  699: 679,
#  522: 678,
#  495: 677,
#  25: 676,
#  42: 675,
#  380: 674,
#  381: 673,
#  356: 672,
#  482: 671,
#  675: 670,
#  128: 669,
#  708: 668,
#  709: 667,
#  89: 666,
#  76: 665,
#  437: 664,
#  701: 663,
#  702: 662,
#  506: 661,
#  531: 660,
#  723: 659,
#  720: 658,
#  722: 657,
#  719: 656,
#  737: 655,
#  559: 654,
#  347: 653,
#  668: 652,
#  673: 651,
#  298: 650,
#  287: 649,
#  448: 648,
#  249: 647,
#  767: 646,
#  108: 645,
#  529: 644,
#  725: 643,
#  718: 642,
#  733: 641,
#  383: 640,
#  615: 639,
#  374: 638,
#  379: 637,
#  658: 636,
#  662: 635,
#  295: 634,
#  370: 633,
#  288: 632,
#  282: 631,
#  208: 630,
#  435: 629,
#  434: 628,
#  393: 627,
#  494: 626,
#  497: 625,
#  729: 624,
#  715: 623,
#  731: 622,
#  739: 621,
#  617: 620,
#  823: 619,
#  618: 618,
#  614: 617,
#  490: 616,
#  666: 615,
#  670: 614,
#  294: 613,
#  302: 612,
#  304: 611,
#  283: 610,
#  542: 609,
#  143: 608,
#  144: 607,
#  414: 606,
#  285: 605,
#  323: 604,
#  438: 603,
#  498: 602,
#  500: 601,
#  501: 600,
#  502: 599,
#  503: 598,
#  504: 597,
#  508: 596,
#  509: 595,
#  499: 594,
#  728: 593,
#  724: 592,
#  58: 591,
#  616: 590,
#  671: 589,
#  674: 588,
#  296: 587,
#  299: 586,
#  303: 585,
#  306: 584,
#  307: 583,
#  326: 582,
#  324: 581,
#  327: 580,
#  826: 579,
#  829: 578,
#  325: 577,
#  831: 576,
#  799: 575,
#  838: 574,
#  82: 573,
#  423: 572,
#  428: 571,
#  236: 570,
#  507: 569,
#  713: 568,
#  735: 567,
#  46: 566,
#  931: 565,
#  41: 564,
#  360: 563,
#  491: 562,
#  466: 561,
#  5: 560,
#  669: 559,
#  309: 558,
#  301: 557,
#  305: 556,
#  328: 555,
#  825: 554,
#  828: 553,
#  827: 552,
#  830: 551,
#  205: 550,
#  773: 549,
#  350: 548,
#  369: 547,
#  255: 546,
#  99: 545,
#  408: 544,
#  736: 543,
#  727: 542,
#  721: 541,
#  732: 540,
#  716: 539,
#  16: 538,
#  18: 537,
#  29: 536,
#  32: 535,
#  930: 534,
#  929: 533,
#  37: 532,
#  844: 531,
#  34: 530,
#  832: 529,
#  440: 528,
#  456: 527,
#  462: 526,
#  797: 525,
#  429: 524,
#  404: 523,
#  238: 522,
#  810: 521,
#  726: 520,
#  717: 519,
#  44: 518,
#  68: 517,
#  30: 516,
#  48: 515,
#  49: 514,
#  50: 513,
#  51: 512,
#  73: 511,
#  35: 510,
#  784: 509,
#  38: 508,
#  12: 507,
#  119: 506,
#  633: 505,
#  8: 504,
#  147: 503,
#  149: 502,
#  774: 501,
#  289: 500,
#  192: 499,
#  78: 498,
#  837: 497,
#  21: 496,
#  47: 495,
#  40: 494,
#  349: 493,
#  786: 492,
#  346: 491,
#  377: 490,
#  779: 489,
#  492: 488,
#  676: 487,
#  118: 486,
#  122: 485,
#  704: 484,
#  133: 483,
#  206: 482,
#  142: 481,
#  772: 480,
#  775: 479,
#  368: 478,
#  754: 477,
#  341: 476,
#  243: 475,
#  549: 474,
#  431: 473,
#  407: 472,
#  60: 471,
#  45: 470,
#  27: 469,
#  28: 468,
#  43: 467,
#  52: 466,
#  751: 465,
#  783: 464,
#  785: 463,
#  354: 462,
#  355: 461,
#  780: 460,
#  932: 459,
#  13: 458,
#  644: 457,
#  808: 456,
#  209: 455,
#  776: 454,
#  371: 453,
#  753: 452,
#  755: 451,
#  756: 450,
#  757: 449,
#  759: 448,
#  760: 447,
#  761: 446,
#  762: 445,
#  284: 444,
#  397: 443,
#  248: 442,
#  432: 441,
#  36: 440,
#  15: 439,
#  53: 438,
#  782: 437,
#  787: 436,
#  363: 435,
#  489: 434,
#  882: 433,
#  636: 432,
#  643: 431,
#  336: 430,
#  338: 429,
#  959: 428,
#  539: 427,
#  852: 426,
#  544: 425,
#  913: 424,
#  758: 423,
#  290: 422,
#  281: 421,
#  467: 420,
#  455: 419,
#  465: 418,
#  652: 417,
#  84: 416,
#  411: 415,
#  741: 414,
#  19: 413,
#  57: 412,
#  582: 411,
#  358: 410,
#  345: 409,
#  361: 408,
#  463: 407,
#  879: 406,
#  919: 405,
#  918: 404,
#  11: 403,
#  634: 402,
#  654: 401,
#  878: 400,
#  884: 399,
#  748: 398,
#  873: 397,
#  677: 396,
#  679: 395,
#  329: 394,
#  317: 393,
#  316: 392,
#  685: 391,
#  538: 390,
#  543: 389,
#  545: 388,
#  131: 387,
#  647: 386,
#  648: 385,
#  650: 384,
#  651: 383,
#  207: 382,
#  681: 381,
#  454: 380,
#  268: 379,
#  976: 378,
#  550: 377,
#  293: 376,
#  839: 375,
#  764: 374,
#  436: 373,
#  115: 372,
#  220: 371,
#  392: 370,
#  412: 369,
#  26: 368,
#  65: 367,
#  769: 366,
#  364: 365,
#  626: 364,
#  628: 363,
#  629: 362,
#  4: 361,
#  630: 360,
#  881: 359,
#  635: 358,
#  883: 357,
#  0: 356,
#  640: 355,
#  921: 354,
#  922: 353,
#  885: 352,
#  924: 351,
#  624: 350,
#  896: 349,
#  898: 348,
#  331: 347,
#  310: 346,
#  332: 345,
#  333: 344,
#  540: 343,
#  853: 342,
#  854: 341,
#  855: 340,
#  856: 339,
#  857: 338,
#  858: 337,
#  788: 336,
#  703: 335,
#  778: 334,
#  409: 333,
#  458: 332,
#  445: 331,
#  279: 330,
#  405: 329,
#  820: 328,
#  821: 327,
#  818: 326,
#  817: 325,
#  819: 324,
#  845: 323,
#  977: 322,
#  72: 321,
#  800: 320,
#  801: 319,
#  63: 318,
#  443: 317,
#  439: 316,
#  581: 315,
#  583: 314,
#  558: 313,
#  348: 312,
#  621: 311,
#  791: 310,
#  805: 309,
#  920: 308,
#  6: 307,
#  872: 306,
#  641: 305,
#  886: 304,
#  874: 303,
#  623: 302,
#  637: 301,
#  897: 300,
#  308: 299,
#  895: 298,
#  688: 297,
#  686: 296,
#  689: 295,
#  334: 294,
#  833: 293,
#  546: 292,
#  888: 291,
#  951: 290,
#  692: 289,
#  694: 288,
#  695: 287,
#  696: 286,
#  451: 285,
#  449: 284,
#  402: 283,
#  430: 282,
#  541: 281,
#  406: 280,
#  400: 279,
#  398: 278,
#  413: 277,
#  530: 276,
#  967: 275,
#  33: 274,
#  61: 273,
#  970: 272,
#  59: 271,
#  352: 270,
#  770: 269,
#  781: 268,
#  2: 267,
#  3: 266,
#  875: 265,
#  908: 264,
#  536: 263,
#  537: 262,
#  809: 261,
#  55: 260,
#  880: 259,
#  631: 258,
#  946: 257,
#  632: 256,
#  639: 255,
#  645: 254,
#  923: 253,
#  903: 252,
#  638: 251,
#  747: 250,
#  678: 249,
#  312: 248,
#  318: 247,
#  330: 246,
#  899: 245,
#  937: 244,
#  916: 243,
#  864: 242,
#  866: 241,
#  867: 240,
#  401: 239,
#  687: 238,
#  690: 237,
#  320: 236,
#  337: 235,
#  121: 234,
#  790: 233,
#  745: 232,
#  777: 231,
#  958: 230,
#  693: 229,
#  7: 228,
#  459: 227,
#  373: 226,
#  403: 225,
#  291: 224,
#  551: 223,
#  940: 222,
#  763: 221,
#  113: 220,
#  683: 219,
#  442: 218,
#  796: 217,
#  416: 216,
#  891: 215,
#  528: 214,
#  527: 213,
#  74: 212,
#  803: 211,
#  62: 210,
#  945: 209,
#  71: 208,
#  611: 207,
#  752: 206,
#  768: 205,
#  375: 204,
#  359: 203,
#  771: 202,
#  351: 201,
#  493: 200,
#  907: 199,
#  806: 198,
#  807: 197,
#  56: 196,
#  876: 195,
#  904: 194,
#  613: 193,
#  947: 192,
#  917: 191,
#  865: 190,
#  868: 189,
#  869: 188,
#  893: 187,
#  339: 186,
#  964: 185,
#  441: 184,
#  824: 183,
#  319: 182,
#  322: 181,
#  890: 180,
#  889: 179,
#  925: 178,
#  910: 177,
#  927: 176,
#  680: 175,
#  343: 174,
#  979: 173,
#  765: 172,
#  553: 171,
#  986: 170,
#  552: 169,
#  960: 168,
#  684: 167,
#  991: 166,
#  410: 165,
#  390: 164,
#  418: 163,
#  417: 162,
#  822: 161,
#  846: 160,
#  835: 159,
#  742: 158,
#  834: 157,
#  31: 156,
#  64: 155,
#  804: 154,
#  939: 153,
#  944: 152,
#  70: 151,
#  697: 150,
#  968: 149,
#  969: 148,
#  802: 147,
#  981: 146,
#  584: 145,
#  793: 144,
#  367: 143,
#  366: 142,
#  794: 141,
#  996: 140,
#  642: 139,
#  653: 138,
#  901: 137,
#  933: 136,
#  934: 135,
#  943: 134,
#  949: 133,
#  750: 132,
#  963: 131,
#  948: 130,
#  992: 129,
#  10: 128,
#  535: 127,
#  749: 126,
#  900: 125,
#  840: 124,
#  911: 123,
#  870: 122,
#  892: 121,
#  965: 120,
#  706: 119,
#  335: 118,
#  887: 117,
#  950: 116,
#  321: 115,
#  789: 114,
#  744: 113,
#  710: 112,
#  311: 111,
#  952: 110,
#  955: 109,
#  956: 108,
#  957: 107,
#  849: 106,
#  850: 105,
#  980: 104,
#  450: 103,
#  926: 102,
#  994: 101,
#  998: 100,
#  460: 99,
#  746: 98,
#  464: 97,
#  461: 96,
#  457: 95,
#  861: 94,
#  860: 93,
#  344: 92,
#  453: 91,
#  848: 90,
#  993: 89,
#  847: 88,
#  444: 87,
#  116: 86,
#  682: 85,
#  548: 84,
#  547: 83,
#  978: 82,
#  987: 81,
#  975: 80,
#  415: 79,
#  795: 78,
#  974: 77,
#  526: 76,
#  936: 75,
#  842: 74,
#  985: 73,
#  894: 72,
#  740: 71,
#  912: 70,
#  75: 69,
#  836: 68,
#  938: 67,
#  859: 66,
#  69: 65,
#  67: 64,
#  66: 63,
#  971: 62,
#  984: 61,
#  989: 60,
#  999: 59,
#  1002: 58,
#  1003: 57,
#  365: 56,
#  372: 55,
#  622: 54,
#  915: 53,
#  382: 52,
#  705: 51,
#  914: 50,
#  935: 49,
#  941: 48,
#  942: 47,
#  625: 46,
#  862: 45,
#  1: 44,
#  54: 43,
#  877: 42,
#  698: 41,
#  961: 40,
#  906: 39,
#  905: 38,
#  966: 37,
#  972: 36,
#  9: 35,
#  627: 34,
#  988: 33,
#  612: 32,
#  997: 31,
#  1000: 30,
#  1001: 29,
#  655: 28,
#  863: 27,
#  909: 26,
#  962: 25,
#  314: 24,
#  315: 23,
#  928: 22,
#  340: 21,
#  313: 20,
#  871: 19,
#  841: 18,
#  843: 17,
#  691: 16,
#  117: 15,
#  902: 14,
#  125: 13,
#  792: 12,
#  973: 11,
#  990: 10,
#  743: 9,
#  649: 8,
#  711: 7,
#  982: 6,
#  983: 5,
#  ...}

# %%
# Write Centrality
with open('./MapEquationCentralityResults/Bio-YeastCollins/dict_map_eq_centrality.txt', 'w') as f:
    for key, value in dict_map_eq_centrality.items():
        f.write('%s:%s\n' % (key, value))

# %%
# Read Centrality
dict_map_eq_centrality_read = dict()
with open('./MapEquationCentralityResults/Bio-YeastCollins/dict_map_eq_centrality.txt') as raw_data:
    for item in raw_data:
        if ':' in item:
            key,value = item.split(':', 1)
            value = value.replace('\n', '')
            dict_map_eq_centrality_read[int(key)]=float(value)
        else:
            pass # deal with bad lines of text here

# %%
dict_map_eq_centrality_read == dict_map_eq_centrality
# Out:
# True
