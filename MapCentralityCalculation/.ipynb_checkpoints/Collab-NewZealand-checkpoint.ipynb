# %% [markdown]
# # Real-world network

# %%
import networkx as nx
from networkx.algorithms.centrality import *
import numpy as np
import operator
from analysis import *

# %%
g = nx.read_gml("./RealNetworks/new_zealand_collab.gml")

# %%
print(nx.info(g))
# Out:
# Graph with 1463 nodes and 4246 edges
# <ipython-input-3-99dac2172e06>:1: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   print(nx.info(g))

# %% [markdown]
# # Check connectedness

# %%
nx.is_connected(g)
# Out:
# True

# %%
nx.number_connected_components(g)
# Out:
# 1

# %% [markdown]
# # Get LCC if graph is disconnected

# %% [raw]
# """Step 5: If the graph after immunization is disconnected, get the largest component"""
# g_lcc = nx.Graph()
#
# if nx.is_connected(g) == False:
#     largestComponents = [g.subgraph(c).copy() for c in sorted(nx.connected_components(g), key=len, reverse=True)]
#     print(nx.info(largestComponents[0]))
#
# g_lcc=largestComponents[0]
#
# print(nx.info(g_lcc))
#
# g = g_lcc
#
# print(nx.info(g))

# %% [markdown]
# # Relabel it all if nodes are strings
# - To be able to run all types of correlation together
# - But put the graph relabled in `g_relabled`

# %%
from myTruss import mappingAndRelabeling

# %%
g_relabled = mappingAndRelabeling(g)

# %%
print(nx.info(g))
print(nx.info(g_relabled))
# Out:
# Graph with 1463 nodes and 4246 edges
# Graph with 1463 nodes and 4246 edges
# <ipython-input-8-632c4a2d19f6>:1: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   print(nx.info(g))
# <ipython-input-8-632c4a2d19f6>:2: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   print(nx.info(g_relabled))

# %%
g = g_relabled

# %% [markdown]
# # Infer community structure with Louvain

# %%
nx.__version__
# Out:
# '2.8.4'

# %%
import pandas as pd
from os.path  import exists
import infomap as im

# %%
im.__version__
# Out:
# '2.3.0'

# %%
G = g

# %%
partition   = nx.algorithms.community.louvain_communities(G, seed = 0)
partition_Q = nx.algorithms.community.modularity(G, partition)

for seed in Bar("Progress", check_tty = False).iter(range(1,5)):
    partition_   = nx.algorithms.community.louvain_communities(G, seed = seed)
    partition_Q_ = nx.algorithms.community.modularity(G, partition_)
    
    if partition_Q_ > partition_Q:
        partition   = partition_
        partition_Q = partition_Q_
# Out:
# Progress |################################| 4/4

# %%
communities = { community_ID : set(community) for (community_ID, community) in enumerate(partition, start = 1)}

# %%
community_assignments = dict()
for (community_ID, community) in communities.items():
    for node in community:
        community_assignments[node] = community_ID

# %%
results_file = "./results/new_zealand_collab-modularity.csv"

if not exists(results_file):
    # Map Equation Centrality
    tree_file = "./results/new_zealand_collab-temp.tree"

    # use Infomap to write a tree file that we change to reflect the Louvain partition
    infomap = im.Infomap(silent = True, num_trials = 1, directed = False, two_level = True, seed = 42)
    infomap.add_networkx_graph(G)
    infomap.run()
    infomap.write_tree(tree_file)
    
    infomap_tree = dict()

    # read the tree file
    with open(tree_file, "r") as fh:
        for line in fh:
            if not line.startswith("#"):
                _, flow, name, node_id = line.strip().split(" ")
                name = name[1:-1]
                infomap_tree[int(name)] = (flow, node_id)
    
    # write the Louvain partition to an Infomap tree file
    with open("./results/new_zealand_collab-modularity.tree", "w") as fh:
        for community_ID, community in enumerate(partition, start = 1):
            for node_pos, node in enumerate(community, start = 1):
                path = f"{community_ID}:{node_pos}"
                flow, node_id = infomap_tree[node]
                fh.write(f"{path} {flow} \"{node}\" {node_id}\n")
    
    # Load the Louvain partition with Infomap and use unrecorded link teleportation
    infomap2 = im.Infomap("--silent --no-infomap --cluster-data ./results/new_zealand_collab-modularity.tree")
    node_mapping = infomap2.add_networkx_graph(G)
    infomap2.run()
    
    mec_ranks = [node for node, _score in sorted( [ (node_mapping[node.node_id], node.modular_centrality) for node in infomap2.iterLeafNodes() ]
                                                 , key     = second
                                                 , reverse = True
                                                 )]

    
    index = []
    for node in G.nodes:
        index.append(node)

    results = pd.DataFrame(index=index)

    results["map equation centrality rank"]       = toRanking(mec_ranks,        results.index)
    results.to_csv(results_file)

else:
    results = pd.read_csv(results_file, index_col = 0)

    mec_ranks         = mkRanks(results["map equation centrality rank"])

# %%
len(mec_ranks)
# Out:
# 1463

# %%
# node 107 has rank 0 (i.e. 1)
# node 1684 has rank 1 (i.e. 2)
# ...
# node 0 has rank 4 (i.e. 5)
mec_ranks
# Out:
# [7,
#  5,
#  18,
#  1,
#  90,
#  29,
#  17,
#  30,
#  22,
#  19,
#  80,
#  128,
#  33,
#  14,
#  16,
#  45,
#  8,
#  11,
#  307,
#  137,
#  25,
#  175,
#  180,
#  103,
#  211,
#  2,
#  356,
#  361,
#  223,
#  73,
#  95,
#  100,
#  20,
#  299,
#  302,
#  111,
#  192,
#  61,
#  235,
#  121,
#  118,
#  306,
#  63,
#  355,
#  226,
#  359,
#  258,
#  26,
#  15,
#  252,
#  59,
#  62,
#  216,
#  82,
#  392,
#  257,
#  40,
#  23,
#  75,
#  109,
#  279,
#  360,
#  172,
#  270,
#  386,
#  157,
#  195,
#  426,
#  601,
#  193,
#  49,
#  282,
#  88,
#  173,
#  97,
#  489,
#  140,
#  294,
#  348,
#  269,
#  136,
#  452,
#  880,
#  237,
#  501,
#  201,
#  202,
#  122,
#  292,
#  441,
#  241,
#  436,
#  349,
#  187,
#  483,
#  468,
#  199,
#  125,
#  666,
#  382,
#  67,
#  571,
#  690,
#  680,
#  27,
#  619,
#  527,
#  624,
#  178,
#  181,
#  390,
#  91,
#  79,
#  761,
#  240,
#  917,
#  739,
#  696,
#  554,
#  626,
#  381,
#  609,
#  634,
#  740,
#  787,
#  453,
#  267,
#  42,
#  705,
#  738,
#  996,
#  105,
#  418,
#  638,
#  901,
#  428,
#  285,
#  68,
#  663,
#  987,
#  734,
#  368,
#  380,
#  752,
#  284,
#  746,
#  612,
#  275,
#  276,
#  627,
#  120,
#  13,
#  429,
#  48,
#  228,
#  340,
#  600,
#  159,
#  209,
#  135,
#  76,
#  72,
#  71,
#  69,
#  64,
#  498,
#  575,
#  455,
#  493,
#  568,
#  358,
#  573,
#  590,
#  108,
#  297,
#  667,
#  774,
#  693,
#  544,
#  930,
#  654,
#  210,
#  255,
#  70,
#  464,
#  243,
#  1274,
#  605,
#  388,
#  273,
#  879,
#  231,
#  1257,
#  78,
#  572,
#  41,
#  89,
#  385,
#  94,
#  486,
#  167,
#  719,
#  1099,
#  1339,
#  66,
#  65,
#  747,
#  99,
#  362,
#  636,
#  675,
#  31,
#  641,
#  357,
#  471,
#  653,
#  662,
#  754,
#  933,
#  516,
#  278,
#  484,
#  660,
#  528,
#  266,
#  1226,
#  781,
#  686,
#  74,
#  32,
#  495,
#  93,
#  912,
#  101,
#  741,
#  822,
#  317,
#  264,
#  526,
#  46,
#  350,
#  204,
#  488,
#  651,
#  1420,
#  77,
#  1008,
#  1134,
#  98,
#  9,
#  10,
#  12,
#  343,
#  24,
#  28,
#  370,
#  577,
#  341,
#  595,
#  313,
#  432,
#  421,
#  222,
#  1118,
#  1227,
#  1258,
#  728,
#  813,
#  564,
#  176,
#  254,
#  330,
#  458,
#  4,
#  6,
#  3,
#  92,
#  644,
#  384,
#  143,
#  184,
#  665,
#  1004,
#  215,
#  205,
#  961,
#  1205,
#  224,
#  347,
#  300,
#  301,
#  305,
#  834,
#  606,
#  326,
#  177,
#  158,
#  147,
#  472,
#  198,
#  1232,
#  938,
#  1233,
#  465,
#  708,
#  642,
#  113,
#  496,
#  532,
#  940,
#  713,
#  449,
#  475,
#  559,
#  649,
#  681,
#  469,
#  371,
#  372,
#  378,
#  872,
#  280,
#  659,
#  790,
#  171,
#  246,
#  760,
#  971,
#  419,
#  1037,
#  491,
#  287,
#  446,
#  581,
#  844,
#  277,
#  788,
#  780,
#  248,
#  899,
#  327,
#  1191,
#  274,
#  1241,
#  635,
#  283,
#  259,
#  39,
#  55,
#  1050,
#  56,
#  304,
#  396,
#  394,
#  395,
#  438,
#  865,
#  383,
#  915,
#  408,
#  948,
#  979,
#  1003,
#  342,
#  702,
#  569,
#  1287,
#  550,
#  924,
#  621,
#  783,
#  784,
#  785,
#  1379,
#  592,
#  1002,
#  1206,
#  1204,
#  1203,
#  1043,
#  535,
#  927,
#  1176,
#  1175,
#  888,
#  1075,
#  749,
#  1265,
#  1385,
#  166,
#  139,
#  141,
#  155,
#  133,
#  190,
#  196,
#  150,
#  212,
#  1410,
#  1335,
#  534,
#  877,
#  664,
#  599,
#  710,
#  694,
#  707,
#  695,
#  1129,
#  289,
#  104,
#  935,
#  131,
#  918,
#  519,
#  697,
#  545,
#  1247,
#  1025,
#  110,
#  374,
#  298,
#  873,
#  1084,
#  905,
#  805,
#  1183,
#  743,
#  1248,
#  308,
#  874,
#  885,
#  655,
#  440,
#  889,
#  720,
#  691,
#  628,
#  473,
#  51,
#  988,
#  369,
#  373,
#  115,
#  425,
#  980,
#  1240,
#  521,
#  731,
#  251,
#  288,
#  454,
#  398,
#  1014,
#  393,
#  782,
#  230,
#  853,
#  247,
#  851,
#  233,
#  397,
#  286,
#  197,
#  1112,
#  773,
#  637,
#  855,
#  262,
#  334,
#  748,
#  678,
#  1334,
#  858,
#  1260,
#  333,
#  983,
#  250,
#  841,
#  586,
#  522,
#  616,
#  682,
#  316,
#  753,
#  866,
#  828,
#  558,
#  794,
#  802,
#  792,
#  900,
#  864,
#  921,
#  923,
#  416,
#  876,
#  943,
#  778,
#  954,
#  793,
#  479,
#  614,
#  969,
#  764,
#  1111,
#  1046,
#  1045,
#  1407,
#  1303,
#  1273,
#  478,
#  729,
#  217,
#  1307,
#  1314,
#  553,
#  1406,
#  557,
#  1270,
#  447,
#  982,
#  1245,
#  758,
#  1397,
#  116,
#  117,
#  890,
#  1396,
#  824,
#  1165,
#  1172,
#  1353,
#  668,
#  21,
#  850,
#  417,
#  58,
#  410,
#  833,
#  337,
#  759,
#  148,
#  1098,
#  1119,
#  169,
#  1400,
#  1401,
#  142,
#  1272,
#  1431,
#  191,
#  194,
#  149,
#  160,
#  1101,
#  185,
#  81,
#  1120,
#  1289,
#  221,
#  652,
#  1124,
#  763,
#  1224,
#  1100,
#  775,
#  1011,
#  735,
#  474,
#  960,
#  437,
#  574,
#  541,
#  640,
#  902,
#  724,
#  920,
#  995,
#  1113,
#  476,
#  102,
#  1209,
#  1214,
#  565,
#  1087,
#  1092,
#  375,
#  585,
#  596,
#  597,
#  602,
#  607,
#  622,
#  1409,
#  623,
#  391,
#  123,
#  648,
#  919,
#  922,
#  929,
#  650,
#  1180,
#  1181,
#  1446,
#  679,
#  1246,
#  939,
#  1255,
#  435,
#  949,
#  950,
#  766,
#  953,
#  442,
#  444,
#  445,
#  776,
#  974,
#  1293,
#  1328,
#  817,
#  818,
#  311,
#  312,
#  477,
#  862,
#  991,
#  525,
#  490,
#  38,
#  505,
#  1067,
#  1015,
#  503,
#  1040,
#  1053,
#  1091,
#  1115,
#  1123,
#  1135,
#  639,
#  1157,
#  134,
#  1174,
#  744,
#  1185,
#  1188,
#  165,
#  1193,
#  1223,
#  1228,
#  1229,
#  1230,
#  244,
#  242,
#  260,
#  263,
#  1290,
#  268,
#  1259,
#  249,
#  238,
#  236,
#  814,
#  320,
#  232,
#  842,
#  843,
#  846,
#  852,
#  857,
#  351,
#  352,
#  867,
#  1394,
#  1402,
#  387,
#  389,
#  1415,
#  1251,
#  916,
#  1430,
#  925,
#  1440,
#  945,
#  947,
#  456,
#  972,
#  1033,
#  1036,
#  1039,
#  1006,
#  1236,
#  849,
#  127,
#  673,
#  618,
#  657,
#  733,
#  750,
#  765,
#  290,
#  291,
#  563,
#  676,
#  820,
#  84,
#  318,
#  85,
#  683,
#  353,
#  354,
#  692,
#  126,
#  329,
#  433,
#  615,
#  443,
#  461,
#  463,
#  500,
#  674,
#  910,
#  688,
#  723,
#  742,
#  771,
#  896,
#  928,
#  903,
#  898,
#  887,
#  555,
#  829,
#  957,
#  530,
#  970,
#  462,
#  976,
#  978,
#  323,
#  984,
#  986,
#  989,
#  36,
#  992,
#  994,
#  485,
#  124,
#  345,
#  346,
#  499,
#  955,
#  703,
#  963,
#  1220,
#  714,
#  1286,
#  981,
#  0,
#  214,
#  481,
#  1269,
#  914,
#  1296,
#  1278,
#  295,
#  810,
#  52,
#  53,
#  835,
#  836,
#  837,
#  588,
#  482,
#  1369,
#  1377,
#  620,
#  892,
#  1169,
#  1170,
#  411,
#  431,
#  439,
#  1034,
#  1035,
#  271,
#  377,
#  1155,
#  669,
#  1182,
#  671,
#  613,
#  816,
#  1192,
#  815,
#  825,
#  1030,
#  1342,
#  1156,
#  1390,
#  335,
#  220,
#  407,
#  999,
#  823,
#  1007,
#  594,
#  1344,
#  325,
#  845,
#  1125,
#  1198,
#  908,
#  1168,
#  672,
#  1195,
#  1197,
#  1199,
#  515,
#  958,
#  959,
#  1324,
#  225,
#  1001,
#  1325,
#  562,
#  47,
#  303,
#  504,
#  1018,
#  170,
#  174,
#  182,
#  183,
#  1316,
#  807,
#  189,
#  129,
#  1363,
#  138,
#  144,
#  145,
#  200,
#  186,
#  151,
#  208,
#  152,
#  154,
#  213,
#  156,
#  163,
#  203,
#  1159,
#  1423,
#  537,
#  1343,
#  1336,
#  811,
#  1449,
#  44,
#  1311,
#  1282,
#  1162,
#  1448,
#  322,
#  1266,
#  883,
#  1361,
#  1022,
#  767,
#  1029,
#  1056,
#  1057,
#  804,
#  1066,
#  1069,
#  598,
#  1096,
#  1097,
#  399,
#  86,
#  87,
#  1126,
#  904,
#  795,
#  448,
#  736,
#  507,
#  589,
#  868,
#  1131,
#  37,
#  869,
#  1145,
#  1140,
#  895,
#  1268,
#  1207,
#  1109,
#  1213,
#  881,
#  1217,
#  1142,
#  1200,
#  338,
#  1425,
#  1427,
#  1263,
#  1184,
#  1438,
#  1250,
#  112,
#  1443,
#  1094,
#  1090,
#  1445,
#  1089,
#  871,
#  1088,
#  1086,
#  1451,
#  1452,
#  1085,
#  54,
#  1194,
#  875,
#  1044,
#  1026,
#  367,
#  1319,
#  808,
#  1249,
#  1244,
#  1243,
#  1242,
#  1395,
#  1327,
#  376,
#  1252,
#  1254,
#  379,
#  1330,
#  1405,
#  1234,
#  1202,
#  779,
#  1256,
#  799,
#  1201,
#  1416,
#  1016,
#  1017,
#  1023,
#  332,
#  791,
#  1166,
#  854,
#  1267,
#  856,
#  256,
#  119,
#  859,
#  1122,
#  861,
#  798,
#  253,
#  1315,
#  1121,
#  870,
#  1117,
#  245,
#  234,
#  1403,
#  1239,
#  1116,
#  229,
#  281,
#  1238,
#  319,
#  1114,
#  1417,
#  1421,
#  1110,
#  1107,
#  400,
#  1428,
#  786,
#  1429,
#  272,
#  1237,
#  840,
#  1441,
#  1104,
#  1444,
#  1453,
#  1454,
#  1456,
#  ...]

# %%
counter = len(mec_ranks)
dict_map_eq_centrality = {}

# %%
for node in mec_ranks:
    dict_map_eq_centrality[int(node)] = counter
    counter = counter - 1

# %%
dict_map_eq_centrality
# Out:
# {7: 1463,
#  5: 1462,
#  18: 1461,
#  1: 1460,
#  90: 1459,
#  29: 1458,
#  17: 1457,
#  30: 1456,
#  22: 1455,
#  19: 1454,
#  80: 1453,
#  128: 1452,
#  33: 1451,
#  14: 1450,
#  16: 1449,
#  45: 1448,
#  8: 1447,
#  11: 1446,
#  307: 1445,
#  137: 1444,
#  25: 1443,
#  175: 1442,
#  180: 1441,
#  103: 1440,
#  211: 1439,
#  2: 1438,
#  356: 1437,
#  361: 1436,
#  223: 1435,
#  73: 1434,
#  95: 1433,
#  100: 1432,
#  20: 1431,
#  299: 1430,
#  302: 1429,
#  111: 1428,
#  192: 1427,
#  61: 1426,
#  235: 1425,
#  121: 1424,
#  118: 1423,
#  306: 1422,
#  63: 1421,
#  355: 1420,
#  226: 1419,
#  359: 1418,
#  258: 1417,
#  26: 1416,
#  15: 1415,
#  252: 1414,
#  59: 1413,
#  62: 1412,
#  216: 1411,
#  82: 1410,
#  392: 1409,
#  257: 1408,
#  40: 1407,
#  23: 1406,
#  75: 1405,
#  109: 1404,
#  279: 1403,
#  360: 1402,
#  172: 1401,
#  270: 1400,
#  386: 1399,
#  157: 1398,
#  195: 1397,
#  426: 1396,
#  601: 1395,
#  193: 1394,
#  49: 1393,
#  282: 1392,
#  88: 1391,
#  173: 1390,
#  97: 1389,
#  489: 1388,
#  140: 1387,
#  294: 1386,
#  348: 1385,
#  269: 1384,
#  136: 1383,
#  452: 1382,
#  880: 1381,
#  237: 1380,
#  501: 1379,
#  201: 1378,
#  202: 1377,
#  122: 1376,
#  292: 1375,
#  441: 1374,
#  241: 1373,
#  436: 1372,
#  349: 1371,
#  187: 1370,
#  483: 1369,
#  468: 1368,
#  199: 1367,
#  125: 1366,
#  666: 1365,
#  382: 1364,
#  67: 1363,
#  571: 1362,
#  690: 1361,
#  680: 1360,
#  27: 1359,
#  619: 1358,
#  527: 1357,
#  624: 1356,
#  178: 1355,
#  181: 1354,
#  390: 1353,
#  91: 1352,
#  79: 1351,
#  761: 1350,
#  240: 1349,
#  917: 1348,
#  739: 1347,
#  696: 1346,
#  554: 1345,
#  626: 1344,
#  381: 1343,
#  609: 1342,
#  634: 1341,
#  740: 1340,
#  787: 1339,
#  453: 1338,
#  267: 1337,
#  42: 1336,
#  705: 1335,
#  738: 1334,
#  996: 1333,
#  105: 1332,
#  418: 1331,
#  638: 1330,
#  901: 1329,
#  428: 1328,
#  285: 1327,
#  68: 1326,
#  663: 1325,
#  987: 1324,
#  734: 1323,
#  368: 1322,
#  380: 1321,
#  752: 1320,
#  284: 1319,
#  746: 1318,
#  612: 1317,
#  275: 1316,
#  276: 1315,
#  627: 1314,
#  120: 1313,
#  13: 1312,
#  429: 1311,
#  48: 1310,
#  228: 1309,
#  340: 1308,
#  600: 1307,
#  159: 1306,
#  209: 1305,
#  135: 1304,
#  76: 1303,
#  72: 1302,
#  71: 1301,
#  69: 1300,
#  64: 1299,
#  498: 1298,
#  575: 1297,
#  455: 1296,
#  493: 1295,
#  568: 1294,
#  358: 1293,
#  573: 1292,
#  590: 1291,
#  108: 1290,
#  297: 1289,
#  667: 1288,
#  774: 1287,
#  693: 1286,
#  544: 1285,
#  930: 1284,
#  654: 1283,
#  210: 1282,
#  255: 1281,
#  70: 1280,
#  464: 1279,
#  243: 1278,
#  1274: 1277,
#  605: 1276,
#  388: 1275,
#  273: 1274,
#  879: 1273,
#  231: 1272,
#  1257: 1271,
#  78: 1270,
#  572: 1269,
#  41: 1268,
#  89: 1267,
#  385: 1266,
#  94: 1265,
#  486: 1264,
#  167: 1263,
#  719: 1262,
#  1099: 1261,
#  1339: 1260,
#  66: 1259,
#  65: 1258,
#  747: 1257,
#  99: 1256,
#  362: 1255,
#  636: 1254,
#  675: 1253,
#  31: 1252,
#  641: 1251,
#  357: 1250,
#  471: 1249,
#  653: 1248,
#  662: 1247,
#  754: 1246,
#  933: 1245,
#  516: 1244,
#  278: 1243,
#  484: 1242,
#  660: 1241,
#  528: 1240,
#  266: 1239,
#  1226: 1238,
#  781: 1237,
#  686: 1236,
#  74: 1235,
#  32: 1234,
#  495: 1233,
#  93: 1232,
#  912: 1231,
#  101: 1230,
#  741: 1229,
#  822: 1228,
#  317: 1227,
#  264: 1226,
#  526: 1225,
#  46: 1224,
#  350: 1223,
#  204: 1222,
#  488: 1221,
#  651: 1220,
#  1420: 1219,
#  77: 1218,
#  1008: 1217,
#  1134: 1216,
#  98: 1215,
#  9: 1214,
#  10: 1213,
#  12: 1212,
#  343: 1211,
#  24: 1210,
#  28: 1209,
#  370: 1208,
#  577: 1207,
#  341: 1206,
#  595: 1205,
#  313: 1204,
#  432: 1203,
#  421: 1202,
#  222: 1201,
#  1118: 1200,
#  1227: 1199,
#  1258: 1198,
#  728: 1197,
#  813: 1196,
#  564: 1195,
#  176: 1194,
#  254: 1193,
#  330: 1192,
#  458: 1191,
#  4: 1190,
#  6: 1189,
#  3: 1188,
#  92: 1187,
#  644: 1186,
#  384: 1185,
#  143: 1184,
#  184: 1183,
#  665: 1182,
#  1004: 1181,
#  215: 1180,
#  205: 1179,
#  961: 1178,
#  1205: 1177,
#  224: 1176,
#  347: 1175,
#  300: 1174,
#  301: 1173,
#  305: 1172,
#  834: 1171,
#  606: 1170,
#  326: 1169,
#  177: 1168,
#  158: 1167,
#  147: 1166,
#  472: 1165,
#  198: 1164,
#  1232: 1163,
#  938: 1162,
#  1233: 1161,
#  465: 1160,
#  708: 1159,
#  642: 1158,
#  113: 1157,
#  496: 1156,
#  532: 1155,
#  940: 1154,
#  713: 1153,
#  449: 1152,
#  475: 1151,
#  559: 1150,
#  649: 1149,
#  681: 1148,
#  469: 1147,
#  371: 1146,
#  372: 1145,
#  378: 1144,
#  872: 1143,
#  280: 1142,
#  659: 1141,
#  790: 1140,
#  171: 1139,
#  246: 1138,
#  760: 1137,
#  971: 1136,
#  419: 1135,
#  1037: 1134,
#  491: 1133,
#  287: 1132,
#  446: 1131,
#  581: 1130,
#  844: 1129,
#  277: 1128,
#  788: 1127,
#  780: 1126,
#  248: 1125,
#  899: 1124,
#  327: 1123,
#  1191: 1122,
#  274: 1121,
#  1241: 1120,
#  635: 1119,
#  283: 1118,
#  259: 1117,
#  39: 1116,
#  55: 1115,
#  1050: 1114,
#  56: 1113,
#  304: 1112,
#  396: 1111,
#  394: 1110,
#  395: 1109,
#  438: 1108,
#  865: 1107,
#  383: 1106,
#  915: 1105,
#  408: 1104,
#  948: 1103,
#  979: 1102,
#  1003: 1101,
#  342: 1100,
#  702: 1099,
#  569: 1098,
#  1287: 1097,
#  550: 1096,
#  924: 1095,
#  621: 1094,
#  783: 1093,
#  784: 1092,
#  785: 1091,
#  1379: 1090,
#  592: 1089,
#  1002: 1088,
#  1206: 1087,
#  1204: 1086,
#  1203: 1085,
#  1043: 1084,
#  535: 1083,
#  927: 1082,
#  1176: 1081,
#  1175: 1080,
#  888: 1079,
#  1075: 1078,
#  749: 1077,
#  1265: 1076,
#  1385: 1075,
#  166: 1074,
#  139: 1073,
#  141: 1072,
#  155: 1071,
#  133: 1070,
#  190: 1069,
#  196: 1068,
#  150: 1067,
#  212: 1066,
#  1410: 1065,
#  1335: 1064,
#  534: 1063,
#  877: 1062,
#  664: 1061,
#  599: 1060,
#  710: 1059,
#  694: 1058,
#  707: 1057,
#  695: 1056,
#  1129: 1055,
#  289: 1054,
#  104: 1053,
#  935: 1052,
#  131: 1051,
#  918: 1050,
#  519: 1049,
#  697: 1048,
#  545: 1047,
#  1247: 1046,
#  1025: 1045,
#  110: 1044,
#  374: 1043,
#  298: 1042,
#  873: 1041,
#  1084: 1040,
#  905: 1039,
#  805: 1038,
#  1183: 1037,
#  743: 1036,
#  1248: 1035,
#  308: 1034,
#  874: 1033,
#  885: 1032,
#  655: 1031,
#  440: 1030,
#  889: 1029,
#  720: 1028,
#  691: 1027,
#  628: 1026,
#  473: 1025,
#  51: 1024,
#  988: 1023,
#  369: 1022,
#  373: 1021,
#  115: 1020,
#  425: 1019,
#  980: 1018,
#  1240: 1017,
#  521: 1016,
#  731: 1015,
#  251: 1014,
#  288: 1013,
#  454: 1012,
#  398: 1011,
#  1014: 1010,
#  393: 1009,
#  782: 1008,
#  230: 1007,
#  853: 1006,
#  247: 1005,
#  851: 1004,
#  233: 1003,
#  397: 1002,
#  286: 1001,
#  197: 1000,
#  1112: 999,
#  773: 998,
#  637: 997,
#  855: 996,
#  262: 995,
#  334: 994,
#  748: 993,
#  678: 992,
#  1334: 991,
#  858: 990,
#  1260: 989,
#  333: 988,
#  983: 987,
#  250: 986,
#  841: 985,
#  586: 984,
#  522: 983,
#  616: 982,
#  682: 981,
#  316: 980,
#  753: 979,
#  866: 978,
#  828: 977,
#  558: 976,
#  794: 975,
#  802: 974,
#  792: 973,
#  900: 972,
#  864: 971,
#  921: 970,
#  923: 969,
#  416: 968,
#  876: 967,
#  943: 966,
#  778: 965,
#  954: 964,
#  793: 963,
#  479: 962,
#  614: 961,
#  969: 960,
#  764: 959,
#  1111: 958,
#  1046: 957,
#  1045: 956,
#  1407: 955,
#  1303: 954,
#  1273: 953,
#  478: 952,
#  729: 951,
#  217: 950,
#  1307: 949,
#  1314: 948,
#  553: 947,
#  1406: 946,
#  557: 945,
#  1270: 944,
#  447: 943,
#  982: 942,
#  1245: 941,
#  758: 940,
#  1397: 939,
#  116: 938,
#  117: 937,
#  890: 936,
#  1396: 935,
#  824: 934,
#  1165: 933,
#  1172: 932,
#  1353: 931,
#  668: 930,
#  21: 929,
#  850: 928,
#  417: 927,
#  58: 926,
#  410: 925,
#  833: 924,
#  337: 923,
#  759: 922,
#  148: 921,
#  1098: 920,
#  1119: 919,
#  169: 918,
#  1400: 917,
#  1401: 916,
#  142: 915,
#  1272: 914,
#  1431: 913,
#  191: 912,
#  194: 911,
#  149: 910,
#  160: 909,
#  1101: 908,
#  185: 907,
#  81: 906,
#  1120: 905,
#  1289: 904,
#  221: 903,
#  652: 902,
#  1124: 901,
#  763: 900,
#  1224: 899,
#  1100: 898,
#  775: 897,
#  1011: 896,
#  735: 895,
#  474: 894,
#  960: 893,
#  437: 892,
#  574: 891,
#  541: 890,
#  640: 889,
#  902: 888,
#  724: 887,
#  920: 886,
#  995: 885,
#  1113: 884,
#  476: 883,
#  102: 882,
#  1209: 881,
#  1214: 880,
#  565: 879,
#  1087: 878,
#  1092: 877,
#  375: 876,
#  585: 875,
#  596: 874,
#  597: 873,
#  602: 872,
#  607: 871,
#  622: 870,
#  1409: 869,
#  623: 868,
#  391: 867,
#  123: 866,
#  648: 865,
#  919: 864,
#  922: 863,
#  929: 862,
#  650: 861,
#  1180: 860,
#  1181: 859,
#  1446: 858,
#  679: 857,
#  1246: 856,
#  939: 855,
#  1255: 854,
#  435: 853,
#  949: 852,
#  950: 851,
#  766: 850,
#  953: 849,
#  442: 848,
#  444: 847,
#  445: 846,
#  776: 845,
#  974: 844,
#  1293: 843,
#  1328: 842,
#  817: 841,
#  818: 840,
#  311: 839,
#  312: 838,
#  477: 837,
#  862: 836,
#  991: 835,
#  525: 834,
#  490: 833,
#  38: 832,
#  505: 831,
#  1067: 830,
#  1015: 829,
#  503: 828,
#  1040: 827,
#  1053: 826,
#  1091: 825,
#  1115: 824,
#  1123: 823,
#  1135: 822,
#  639: 821,
#  1157: 820,
#  134: 819,
#  1174: 818,
#  744: 817,
#  1185: 816,
#  1188: 815,
#  165: 814,
#  1193: 813,
#  1223: 812,
#  1228: 811,
#  1229: 810,
#  1230: 809,
#  244: 808,
#  242: 807,
#  260: 806,
#  263: 805,
#  1290: 804,
#  268: 803,
#  1259: 802,
#  249: 801,
#  238: 800,
#  236: 799,
#  814: 798,
#  320: 797,
#  232: 796,
#  842: 795,
#  843: 794,
#  846: 793,
#  852: 792,
#  857: 791,
#  351: 790,
#  352: 789,
#  867: 788,
#  1394: 787,
#  1402: 786,
#  387: 785,
#  389: 784,
#  1415: 783,
#  1251: 782,
#  916: 781,
#  1430: 780,
#  925: 779,
#  1440: 778,
#  945: 777,
#  947: 776,
#  456: 775,
#  972: 774,
#  1033: 773,
#  1036: 772,
#  1039: 771,
#  1006: 770,
#  1236: 769,
#  849: 768,
#  127: 767,
#  673: 766,
#  618: 765,
#  657: 764,
#  733: 763,
#  750: 762,
#  765: 761,
#  290: 760,
#  291: 759,
#  563: 758,
#  676: 757,
#  820: 756,
#  84: 755,
#  318: 754,
#  85: 753,
#  683: 752,
#  353: 751,
#  354: 750,
#  692: 749,
#  126: 748,
#  329: 747,
#  433: 746,
#  615: 745,
#  443: 744,
#  461: 743,
#  463: 742,
#  500: 741,
#  674: 740,
#  910: 739,
#  688: 738,
#  723: 737,
#  742: 736,
#  771: 735,
#  896: 734,
#  928: 733,
#  903: 732,
#  898: 731,
#  887: 730,
#  555: 729,
#  829: 728,
#  957: 727,
#  530: 726,
#  970: 725,
#  462: 724,
#  976: 723,
#  978: 722,
#  323: 721,
#  984: 720,
#  986: 719,
#  989: 718,
#  36: 717,
#  992: 716,
#  994: 715,
#  485: 714,
#  124: 713,
#  345: 712,
#  346: 711,
#  499: 710,
#  955: 709,
#  703: 708,
#  963: 707,
#  1220: 706,
#  714: 705,
#  1286: 704,
#  981: 703,
#  0: 702,
#  214: 701,
#  481: 700,
#  1269: 699,
#  914: 698,
#  1296: 697,
#  1278: 696,
#  295: 695,
#  810: 694,
#  52: 693,
#  53: 692,
#  835: 691,
#  836: 690,
#  837: 689,
#  588: 688,
#  482: 687,
#  1369: 686,
#  1377: 685,
#  620: 684,
#  892: 683,
#  1169: 682,
#  1170: 681,
#  411: 680,
#  431: 679,
#  439: 678,
#  1034: 677,
#  1035: 676,
#  271: 675,
#  377: 674,
#  1155: 673,
#  669: 672,
#  1182: 671,
#  671: 670,
#  613: 669,
#  816: 668,
#  1192: 667,
#  815: 666,
#  825: 665,
#  1030: 664,
#  1342: 663,
#  1156: 662,
#  1390: 661,
#  335: 660,
#  220: 659,
#  407: 658,
#  999: 657,
#  823: 656,
#  1007: 655,
#  594: 654,
#  1344: 653,
#  325: 652,
#  845: 651,
#  1125: 650,
#  1198: 649,
#  908: 648,
#  1168: 647,
#  672: 646,
#  1195: 645,
#  1197: 644,
#  1199: 643,
#  515: 642,
#  958: 641,
#  959: 640,
#  1324: 639,
#  225: 638,
#  1001: 637,
#  1325: 636,
#  562: 635,
#  47: 634,
#  303: 633,
#  504: 632,
#  1018: 631,
#  170: 630,
#  174: 629,
#  182: 628,
#  183: 627,
#  1316: 626,
#  807: 625,
#  189: 624,
#  129: 623,
#  1363: 622,
#  138: 621,
#  144: 620,
#  145: 619,
#  200: 618,
#  186: 617,
#  151: 616,
#  208: 615,
#  152: 614,
#  154: 613,
#  213: 612,
#  156: 611,
#  163: 610,
#  203: 609,
#  1159: 608,
#  1423: 607,
#  537: 606,
#  1343: 605,
#  1336: 604,
#  811: 603,
#  1449: 602,
#  44: 601,
#  1311: 600,
#  1282: 599,
#  1162: 598,
#  1448: 597,
#  322: 596,
#  1266: 595,
#  883: 594,
#  1361: 593,
#  1022: 592,
#  767: 591,
#  1029: 590,
#  1056: 589,
#  1057: 588,
#  804: 587,
#  1066: 586,
#  1069: 585,
#  598: 584,
#  1096: 583,
#  1097: 582,
#  399: 581,
#  86: 580,
#  87: 579,
#  1126: 578,
#  904: 577,
#  795: 576,
#  448: 575,
#  736: 574,
#  507: 573,
#  589: 572,
#  868: 571,
#  1131: 570,
#  37: 569,
#  869: 568,
#  1145: 567,
#  1140: 566,
#  895: 565,
#  1268: 564,
#  1207: 563,
#  1109: 562,
#  1213: 561,
#  881: 560,
#  1217: 559,
#  1142: 558,
#  1200: 557,
#  338: 556,
#  1425: 555,
#  1427: 554,
#  1263: 553,
#  1184: 552,
#  1438: 551,
#  1250: 550,
#  112: 549,
#  1443: 548,
#  1094: 547,
#  1090: 546,
#  1445: 545,
#  1089: 544,
#  871: 543,
#  1088: 542,
#  1086: 541,
#  1451: 540,
#  1452: 539,
#  1085: 538,
#  54: 537,
#  1194: 536,
#  875: 535,
#  1044: 534,
#  1026: 533,
#  367: 532,
#  1319: 531,
#  808: 530,
#  1249: 529,
#  1244: 528,
#  1243: 527,
#  1242: 526,
#  1395: 525,
#  1327: 524,
#  376: 523,
#  1252: 522,
#  1254: 521,
#  379: 520,
#  1330: 519,
#  1405: 518,
#  1234: 517,
#  1202: 516,
#  779: 515,
#  1256: 514,
#  799: 513,
#  1201: 512,
#  1416: 511,
#  1016: 510,
#  1017: 509,
#  1023: 508,
#  332: 507,
#  791: 506,
#  1166: 505,
#  854: 504,
#  1267: 503,
#  856: 502,
#  256: 501,
#  119: 500,
#  859: 499,
#  1122: 498,
#  861: 497,
#  798: 496,
#  253: 495,
#  1315: 494,
#  1121: 493,
#  870: 492,
#  1117: 491,
#  245: 490,
#  234: 489,
#  1403: 488,
#  1239: 487,
#  1116: 486,
#  229: 485,
#  281: 484,
#  1238: 483,
#  319: 482,
#  1114: 481,
#  1417: 480,
#  1421: 479,
#  1110: 478,
#  1107: 477,
#  400: 476,
#  1428: 475,
#  786: 474,
#  1429: 473,
#  272: 472,
#  1237: 471,
#  840: 470,
#  1441: 469,
#  1104: 468,
#  1444: 467,
#  1453: 466,
#  1454: 465,
#  1456: 464,
#  ...}

# %%
# Write Centrality
with open('./MapEquationCentralityResults/Collab-NewZealand/dict_map_eq_centrality.txt', 'w') as f:
    for key, value in dict_map_eq_centrality.items():
        f.write('%s:%s\n' % (key, value))

# %%
# Read Centrality
dict_map_eq_centrality_read = dict()
with open('./MapEquationCentralityResults/Collab-NewZealand/dict_map_eq_centrality.txt') as raw_data:
    for item in raw_data:
        if ':' in item:
            key,value = item.split(':', 1)
            value = value.replace('\n', '')
            dict_map_eq_centrality_read[int(key)]=float(value)
        else:
            pass # deal with bad lines of text here

# %%
dict_map_eq_centrality_read == dict_map_eq_centrality
# Out:
# True
