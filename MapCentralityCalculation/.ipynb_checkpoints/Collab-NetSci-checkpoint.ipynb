# %% [markdown]
# # Real-world network

# %%
import networkx as nx
from networkx.algorithms.centrality import *
import numpy as np
import operator
from analysis import *

# %%
g = nx.read_gml("./RealNetworks/netsci.gml")

# %%
print(nx.info(g))
# Out:
# Graph with 379 nodes and 914 edges
# <ipython-input-3-99dac2172e06>:1: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   print(nx.info(g))

# %% [markdown]
# # Check connectedness

# %%
nx.is_connected(g)
# Out:
# True

# %%
nx.number_connected_components(g)
# Out:
# 1

# %% [markdown]
# # Get LCC if graph is disconnected

# %% [raw]
# """Step 5: If the graph after immunization is disconnected, get the largest component"""
# g_lcc = nx.Graph()
#
# if nx.is_connected(g) == False:
#     largestComponents = [g.subgraph(c).copy() for c in sorted(nx.connected_components(g), key=len, reverse=True)]
#     print(nx.info(largestComponents[0]))
#
# g_lcc=largestComponents[0]
#
# print(nx.info(g_lcc))
#
# g = g_lcc
#
# print(nx.info(g))

# %% [markdown]
# # Relabel it all if nodes are strings
# - To be able to run all types of correlation together
# - But put the graph relabled in `g_relabled`

# %%
from myTruss import mappingAndRelabeling

# %%
g_relabled = mappingAndRelabeling(g)

# %%
print(nx.info(g))
print(nx.info(g_relabled))
# Out:
# Graph with 379 nodes and 914 edges
# Graph with 379 nodes and 914 edges
# <ipython-input-8-632c4a2d19f6>:1: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   print(nx.info(g))
# <ipython-input-8-632c4a2d19f6>:2: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   print(nx.info(g_relabled))

# %%
g = g_relabled

# %% [markdown]
# # Infer community structure with Louvain

# %%
nx.__version__
# Out:
# '2.8.4'

# %%
import pandas as pd
from os.path  import exists
import infomap as im

# %%
im.__version__
# Out:
# '2.3.0'

# %%
G = g

# %%
partition   = nx.algorithms.community.louvain_communities(G, seed = 0)
partition_Q = nx.algorithms.community.modularity(G, partition)

for seed in Bar("Progress", check_tty = False).iter(range(1,5)):
    partition_   = nx.algorithms.community.louvain_communities(G, seed = seed)
    partition_Q_ = nx.algorithms.community.modularity(G, partition_)
    
    if partition_Q_ > partition_Q:
        partition   = partition_
        partition_Q = partition_Q_
# Out:
# Progress |################################| 4/4

# %%
communities = { community_ID : set(community) for (community_ID, community) in enumerate(partition, start = 1)}

# %%
community_assignments = dict()
for (community_ID, community) in communities.items():
    for node in community:
        community_assignments[node] = community_ID

# %%
results_file = "./results/netsci-modularity.csv"

if not exists(results_file):
    # Map Equation Centrality
    tree_file = "./results/netsci-temp.tree"

    # use Infomap to write a tree file that we change to reflect the Louvain partition
    infomap = im.Infomap(silent = True, num_trials = 1, directed = False, two_level = True, seed = 42)
    infomap.add_networkx_graph(G)
    infomap.run()
    infomap.write_tree(tree_file)
    
    infomap_tree = dict()

    # read the tree file
    with open(tree_file, "r") as fh:
        for line in fh:
            if not line.startswith("#"):
                _, flow, name, node_id = line.strip().split(" ")
                name = name[1:-1]
                infomap_tree[int(name)] = (flow, node_id)
    
    # write the Louvain partition to an Infomap tree file
    with open("./results/netsci-modularity.tree", "w") as fh:
        for community_ID, community in enumerate(partition, start = 1):
            for node_pos, node in enumerate(community, start = 1):
                path = f"{community_ID}:{node_pos}"
                flow, node_id = infomap_tree[node]
                fh.write(f"{path} {flow} \"{node}\" {node_id}\n")
    
    # Load the Louvain partition with Infomap and use unrecorded link teleportation
    infomap2 = im.Infomap("--silent --no-infomap --cluster-data ./results/netsci-modularity.tree")
    node_mapping = infomap2.add_networkx_graph(G)
    infomap2.run()
    
    mec_ranks = [node for node, _score in sorted( [ (node_mapping[node.node_id], node.modular_centrality) for node in infomap2.iterLeafNodes() ]
                                                 , key     = second
                                                 , reverse = True
                                                 )]

    
    index = []
    for node in G.nodes:
        index.append(node)

    results = pd.DataFrame(index=index)

    results["map equation centrality rank"]       = toRanking(mec_ranks,        results.index)
    results.to_csv(results_file)

else:
    results = pd.read_csv(results_file, index_col = 0)

    mec_ranks         = mkRanks(results["map equation centrality rank"])

# %%
len(mec_ranks)
# Out:
# 379

# %%
# node 107 has rank 0 (i.e. 1)
# node 1684 has rank 1 (i.e. 2)
# ...
# node 0 has rank 4 (i.e. 5)
mec_ranks
# Out:
# [3,
#  4,
#  58,
#  5,
#  72,
#  219,
#  13,
#  119,
#  142,
#  7,
#  106,
#  107,
#  189,
#  41,
#  44,
#  234,
#  235,
#  93,
#  8,
#  173,
#  53,
#  187,
#  166,
#  94,
#  96,
#  249,
#  250,
#  252,
#  1,
#  14,
#  232,
#  95,
#  62,
#  46,
#  11,
#  74,
#  362,
#  141,
#  295,
#  75,
#  122,
#  246,
#  118,
#  15,
#  16,
#  28,
#  29,
#  257,
#  259,
#  76,
#  123,
#  268,
#  233,
#  81,
#  20,
#  225,
#  241,
#  238,
#  240,
#  239,
#  261,
#  40,
#  42,
#  124,
#  247,
#  248,
#  251,
#  253,
#  162,
#  163,
#  369,
#  217,
#  267,
#  329,
#  9,
#  68,
#  227,
#  220,
#  221,
#  260,
#  262,
#  263,
#  87,
#  293,
#  298,
#  299,
#  300,
#  301,
#  302,
#  193,
#  146,
#  204,
#  156,
#  354,
#  43,
#  126,
#  209,
#  51,
#  200,
#  201,
#  178,
#  179,
#  265,
#  266,
#  269,
#  270,
#  167,
#  18,
#  19,
#  286,
#  113,
#  32,
#  33,
#  361,
#  364,
#  73,
#  222,
#  223,
#  363,
#  360,
#  144,
#  98,
#  100,
#  101,
#  294,
#  188,
#  88,
#  120,
#  127,
#  254,
#  255,
#  210,
#  370,
#  199,
#  216,
#  280,
#  168,
#  169,
#  170,
#  171,
#  172,
#  346,
#  347,
#  320,
#  26,
#  25,
#  6,
#  12,
#  17,
#  27,
#  34,
#  35,
#  38,
#  365,
#  366,
#  367,
#  368,
#  228,
#  226,
#  224,
#  140,
#  143,
#  145,
#  147,
#  102,
#  337,
#  341,
#  105,
#  304,
#  305,
#  306,
#  307,
#  205,
#  206,
#  207,
#  86,
#  50,
#  121,
#  256,
#  211,
#  212,
#  54,
#  59,
#  63,
#  161,
#  47,
#  48,
#  202,
#  283,
#  271,
#  174,
#  175,
#  176,
#  327,
#  331,
#  82,
#  83,
#  84,
#  375,
#  376,
#  377,
#  378,
#  36,
#  349,
#  350,
#  184,
#  21,
#  23,
#  24,
#  30,
#  39,
#  77,
#  229,
#  230,
#  236,
#  237,
#  308,
#  70,
#  71,
#  69,
#  242,
#  243,
#  148,
#  149,
#  150,
#  92,
#  99,
#  112,
#  64,
#  264,
#  10,
#  292,
#  192,
#  195,
#  196,
#  197,
#  335,
#  338,
#  177,
#  190,
#  154,
#  352,
#  353,
#  130,
#  137,
#  138,
#  139,
#  115,
#  116,
#  117,
#  65,
#  66,
#  213,
#  56,
#  57,
#  60,
#  61,
#  160,
#  165,
#  371,
#  159,
#  322,
#  323,
#  324,
#  218,
#  284,
#  285,
#  330,
#  332,
#  372,
#  313,
#  314,
#  348,
#  357,
#  358,
#  359,
#  182,
#  183,
#  37,
#  2,
#  31,
#  325,
#  326,
#  0,
#  78,
#  79,
#  80,
#  309,
#  152,
#  153,
#  97,
#  103,
#  104,
#  108,
#  109,
#  110,
#  111,
#  244,
#  245,
#  258,
#  296,
#  297,
#  303,
#  194,
#  334,
#  336,
#  340,
#  342,
#  151,
#  339,
#  186,
#  191,
#  203,
#  89,
#  157,
#  90,
#  355,
#  356,
#  49,
#  129,
#  131,
#  133,
#  134,
#  135,
#  287,
#  288,
#  290,
#  291,
#  312,
#  311,
#  125,
#  208,
#  214,
#  215,
#  52,
#  55,
#  164,
#  45,
#  279,
#  272,
#  273,
#  275,
#  276,
#  277,
#  328,
#  373,
#  315,
#  316,
#  114,
#  319,
#  181,
#  185,
#  22,
#  91,
#  310,
#  231,
#  344,
#  345,
#  343,
#  85,
#  155,
#  128,
#  132,
#  136,
#  333,
#  289,
#  67,
#  317,
#  158,
#  198,
#  281,
#  282,
#  351,
#  374,
#  274,
#  278,
#  321,
#  318,
#  180]

# %%
counter = len(mec_ranks)
dict_map_eq_centrality = {}

# %%
for node in mec_ranks:
    dict_map_eq_centrality[int(node)] = counter
    counter = counter - 1

# %%
dict_map_eq_centrality
# Out:
# {3: 379,
#  4: 378,
#  58: 377,
#  5: 376,
#  72: 375,
#  219: 374,
#  13: 373,
#  119: 372,
#  142: 371,
#  7: 370,
#  106: 369,
#  107: 368,
#  189: 367,
#  41: 366,
#  44: 365,
#  234: 364,
#  235: 363,
#  93: 362,
#  8: 361,
#  173: 360,
#  53: 359,
#  187: 358,
#  166: 357,
#  94: 356,
#  96: 355,
#  249: 354,
#  250: 353,
#  252: 352,
#  1: 351,
#  14: 350,
#  232: 349,
#  95: 348,
#  62: 347,
#  46: 346,
#  11: 345,
#  74: 344,
#  362: 343,
#  141: 342,
#  295: 341,
#  75: 340,
#  122: 339,
#  246: 338,
#  118: 337,
#  15: 336,
#  16: 335,
#  28: 334,
#  29: 333,
#  257: 332,
#  259: 331,
#  76: 330,
#  123: 329,
#  268: 328,
#  233: 327,
#  81: 326,
#  20: 325,
#  225: 324,
#  241: 323,
#  238: 322,
#  240: 321,
#  239: 320,
#  261: 319,
#  40: 318,
#  42: 317,
#  124: 316,
#  247: 315,
#  248: 314,
#  251: 313,
#  253: 312,
#  162: 311,
#  163: 310,
#  369: 309,
#  217: 308,
#  267: 307,
#  329: 306,
#  9: 305,
#  68: 304,
#  227: 303,
#  220: 302,
#  221: 301,
#  260: 300,
#  262: 299,
#  263: 298,
#  87: 297,
#  293: 296,
#  298: 295,
#  299: 294,
#  300: 293,
#  301: 292,
#  302: 291,
#  193: 290,
#  146: 289,
#  204: 288,
#  156: 287,
#  354: 286,
#  43: 285,
#  126: 284,
#  209: 283,
#  51: 282,
#  200: 281,
#  201: 280,
#  178: 279,
#  179: 278,
#  265: 277,
#  266: 276,
#  269: 275,
#  270: 274,
#  167: 273,
#  18: 272,
#  19: 271,
#  286: 270,
#  113: 269,
#  32: 268,
#  33: 267,
#  361: 266,
#  364: 265,
#  73: 264,
#  222: 263,
#  223: 262,
#  363: 261,
#  360: 260,
#  144: 259,
#  98: 258,
#  100: 257,
#  101: 256,
#  294: 255,
#  188: 254,
#  88: 253,
#  120: 252,
#  127: 251,
#  254: 250,
#  255: 249,
#  210: 248,
#  370: 247,
#  199: 246,
#  216: 245,
#  280: 244,
#  168: 243,
#  169: 242,
#  170: 241,
#  171: 240,
#  172: 239,
#  346: 238,
#  347: 237,
#  320: 236,
#  26: 235,
#  25: 234,
#  6: 233,
#  12: 232,
#  17: 231,
#  27: 230,
#  34: 229,
#  35: 228,
#  38: 227,
#  365: 226,
#  366: 225,
#  367: 224,
#  368: 223,
#  228: 222,
#  226: 221,
#  224: 220,
#  140: 219,
#  143: 218,
#  145: 217,
#  147: 216,
#  102: 215,
#  337: 214,
#  341: 213,
#  105: 212,
#  304: 211,
#  305: 210,
#  306: 209,
#  307: 208,
#  205: 207,
#  206: 206,
#  207: 205,
#  86: 204,
#  50: 203,
#  121: 202,
#  256: 201,
#  211: 200,
#  212: 199,
#  54: 198,
#  59: 197,
#  63: 196,
#  161: 195,
#  47: 194,
#  48: 193,
#  202: 192,
#  283: 191,
#  271: 190,
#  174: 189,
#  175: 188,
#  176: 187,
#  327: 186,
#  331: 185,
#  82: 184,
#  83: 183,
#  84: 182,
#  375: 181,
#  376: 180,
#  377: 179,
#  378: 178,
#  36: 177,
#  349: 176,
#  350: 175,
#  184: 174,
#  21: 173,
#  23: 172,
#  24: 171,
#  30: 170,
#  39: 169,
#  77: 168,
#  229: 167,
#  230: 166,
#  236: 165,
#  237: 164,
#  308: 163,
#  70: 162,
#  71: 161,
#  69: 160,
#  242: 159,
#  243: 158,
#  148: 157,
#  149: 156,
#  150: 155,
#  92: 154,
#  99: 153,
#  112: 152,
#  64: 151,
#  264: 150,
#  10: 149,
#  292: 148,
#  192: 147,
#  195: 146,
#  196: 145,
#  197: 144,
#  335: 143,
#  338: 142,
#  177: 141,
#  190: 140,
#  154: 139,
#  352: 138,
#  353: 137,
#  130: 136,
#  137: 135,
#  138: 134,
#  139: 133,
#  115: 132,
#  116: 131,
#  117: 130,
#  65: 129,
#  66: 128,
#  213: 127,
#  56: 126,
#  57: 125,
#  60: 124,
#  61: 123,
#  160: 122,
#  165: 121,
#  371: 120,
#  159: 119,
#  322: 118,
#  323: 117,
#  324: 116,
#  218: 115,
#  284: 114,
#  285: 113,
#  330: 112,
#  332: 111,
#  372: 110,
#  313: 109,
#  314: 108,
#  348: 107,
#  357: 106,
#  358: 105,
#  359: 104,
#  182: 103,
#  183: 102,
#  37: 101,
#  2: 100,
#  31: 99,
#  325: 98,
#  326: 97,
#  0: 96,
#  78: 95,
#  79: 94,
#  80: 93,
#  309: 92,
#  152: 91,
#  153: 90,
#  97: 89,
#  103: 88,
#  104: 87,
#  108: 86,
#  109: 85,
#  110: 84,
#  111: 83,
#  244: 82,
#  245: 81,
#  258: 80,
#  296: 79,
#  297: 78,
#  303: 77,
#  194: 76,
#  334: 75,
#  336: 74,
#  340: 73,
#  342: 72,
#  151: 71,
#  339: 70,
#  186: 69,
#  191: 68,
#  203: 67,
#  89: 66,
#  157: 65,
#  90: 64,
#  355: 63,
#  356: 62,
#  49: 61,
#  129: 60,
#  131: 59,
#  133: 58,
#  134: 57,
#  135: 56,
#  287: 55,
#  288: 54,
#  290: 53,
#  291: 52,
#  312: 51,
#  311: 50,
#  125: 49,
#  208: 48,
#  214: 47,
#  215: 46,
#  52: 45,
#  55: 44,
#  164: 43,
#  45: 42,
#  279: 41,
#  272: 40,
#  273: 39,
#  275: 38,
#  276: 37,
#  277: 36,
#  328: 35,
#  373: 34,
#  315: 33,
#  316: 32,
#  114: 31,
#  319: 30,
#  181: 29,
#  185: 28,
#  22: 27,
#  91: 26,
#  310: 25,
#  231: 24,
#  344: 23,
#  345: 22,
#  343: 21,
#  85: 20,
#  155: 19,
#  128: 18,
#  132: 17,
#  136: 16,
#  333: 15,
#  289: 14,
#  67: 13,
#  317: 12,
#  158: 11,
#  198: 10,
#  281: 9,
#  282: 8,
#  351: 7,
#  374: 6,
#  274: 5,
#  278: 4,
#  321: 3,
#  318: 2,
#  180: 1}

# %%
# Write Centrality
with open('./MapEquationCentralityResults/Collab-NetSci/dict_map_eq_centrality.txt', 'w') as f:
    for key, value in dict_map_eq_centrality.items():
        f.write('%s:%s\n' % (key, value))

# %%
# Read Centrality
dict_map_eq_centrality_read = dict()
with open('./MapEquationCentralityResults/Collab-NetSci/dict_map_eq_centrality.txt') as raw_data:
    for item in raw_data:
        if ':' in item:
            key,value = item.split(':', 1)
            value = value.replace('\n', '')
            dict_map_eq_centrality_read[int(key)]=float(value)
        else:
            pass # deal with bad lines of text here

# %%
dict_map_eq_centrality_read == dict_map_eq_centrality
# Out:
# True
